# %% [markdown]
# # SimFin Test All Datasets
#
# This Notebook performs automated testing of all the bulk datasets from SimFin. The datasets are first downloaded from the SimFin server and then various tests are performed on the data. An exception is raised if any problems are found.
#
# This Notebook can be run as usual if you have `simfin` installed, by running the following command from the directory where this Notebook is located:
#
#     jupyter notebook
#
# This Notebook can also be run using `pytest` which makes automated testing easier. You need to have the Python packages `simfin` and `nbval` installed. Then execute the following command from the directory where this Notebook is located:
#
#     pytest --nbval-lax test_bulk_data.ipynb
#
# This runs the entire Notebook and outputs error messages for all the cells that raised an exception.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import sys

# %%
import simfin as sf
from simfin.names import *
from simfin.datasets import *

# %% [markdown]
# ## Configure SimFin

# %%
sf.set_data_dir('~/simfin_data/')

# %%
sf.load_api_key(path='~/simfin_api_key.txt', default_key='free')

# %% [markdown]
# ## Load All Datasets

# %%
# %%time
# Use refresh_days=0 to always download new data.
data = AllDatasets(refresh_days=10)
# Out:
# Dataset "markets" is being downloaded ...
# - Download progress: 100.0%
# - Extracting zip-file: Done!
# Loading "ca-income-annual" from disk (0 days old).
# Loading "de-income-annual" from disk (0 days old).
# Loading "it-income-annual" from disk (0 days old).
# Loading "sg-income-annual" from disk (0 days old).
# Loading "us-income-annual" from disk (0 days old).
# Loading "ca-income-annual-full" from disk (0 days old).
# Loading "de-income-annual-full" from disk (0 days old).
# Loading "it-income-annual-full" from disk (0 days old).
# Loading "sg-income-annual-full" from disk (0 days old).
# Loading "us-income-annual-full" from disk (0 days old).
# Loading "ca-income-quarterly" from disk (0 days old).
# Loading "de-income-quarterly" from disk (0 days old).
# Loading "it-income-quarterly" from disk (0 days old).
# Loading "sg-income-quarterly" from disk (0 days old).
# Loading "us-income-quarterly" from disk (0 days old).
# Loading "ca-income-quarterly-full" from disk (0 days old).
# Loading "de-income-quarterly-full" from disk (0 days old).
# Loading "it-income-quarterly-full" from disk (0 days old).
# Loading "sg-income-quarterly-full" from disk (0 days old).
# Loading "us-income-quarterly-full" from disk (0 days old).
# Loading "ca-income-ttm" from disk (0 days old).
# Loading "de-income-ttm" from disk (0 days old).
# Loading "it-income-ttm" from disk (0 days old).
# Loading "sg-income-ttm" from disk (0 days old).
# Loading "us-income-ttm" from disk (0 days old).
# Loading "ca-income-ttm-full" from disk (0 days old).
# Loading "de-income-ttm-full" from disk (0 days old).
# Loading "it-income-ttm-full" from disk (0 days old).
# Loading "sg-income-ttm-full" from disk (0 days old).
# Loading "us-income-ttm-full" from disk (0 days old).
# Loading "ca-income-banks-annual" from disk (0 days old).
# Loading "de-income-banks-annual" from disk (0 days old).
# Loading "it-income-banks-annual" from disk (0 days old).
# Loading "sg-income-banks-annual" from disk (0 days old).
# Loading "us-income-banks-annual" from disk (0 days old).
# Loading "ca-income-banks-annual-full" from disk (0 days old).
# Loading "de-income-banks-annual-full" from disk (0 days old).
# Loading "it-income-banks-annual-full" from disk (0 days old).
# Loading "sg-income-banks-annual-full" from disk (0 days old).
# Loading "us-income-banks-annual-full" from disk (0 days old).
# Loading "ca-income-banks-quarterly" from disk (0 days old).
# Loading "de-income-banks-quarterly" from disk (0 days old).
# Loading "it-income-banks-quarterly" from disk (0 days old).
# Loading "sg-income-banks-quarterly" from disk (0 days old).
# Loading "us-income-banks-quarterly" from disk (0 days old).
# Loading "ca-income-banks-quarterly-full" from disk (0 days old).
# Loading "de-income-banks-quarterly-full" from disk (0 days old).
# Loading "it-income-banks-quarterly-full" from disk (0 days old).
# Loading "sg-income-banks-quarterly-full" from disk (0 days old).
# Loading "us-income-banks-quarterly-full" from disk (0 days old).
# Loading "ca-income-banks-ttm" from disk (0 days old).
# Loading "de-income-banks-ttm" from disk (0 days old).
# Loading "it-income-banks-ttm" from disk (0 days old).
# Loading "sg-income-banks-ttm" from disk (0 days old).
# Loading "us-income-banks-ttm" from disk (0 days old).
# Loading "ca-income-banks-ttm-full" from disk (0 days old).
# Loading "de-income-banks-ttm-full" from disk (0 days old).
# Loading "it-income-banks-ttm-full" from disk (0 days old).
# Loading "sg-income-banks-ttm-full" from disk (0 days old).
# Loading "us-income-banks-ttm-full" from disk (0 days old).
# Loading "ca-income-insurance-annual" from disk (0 days old).
# Loading "de-income-insurance-annual" from disk (0 days old).
# Loading "it-income-insurance-annual" from disk (0 days old).
# Loading "sg-income-insurance-annual" from disk (0 days old).
# Loading "us-income-insurance-annual" from disk (0 days old).
# Loading "ca-income-insurance-annual-full" from disk (0 days old).
# Loading "de-income-insurance-annual-full" from disk (0 days old).
# Loading "it-income-insurance-annual-full" from disk (0 days old).
# Loading "sg-income-insurance-annual-full" from disk (0 days old).
# Loading "us-income-insurance-annual-full" from disk (0 days old).
# Loading "ca-income-insurance-quarterly" from disk (0 days old).
# Loading "de-income-insurance-quarterly" from disk (0 days old).
# Loading "it-income-insurance-quarterly" from disk (0 days old).
# Loading "sg-income-insurance-quarterly" from disk (0 days old).
# Loading "us-income-insurance-quarterly" from disk (0 days old).
# Loading "ca-income-insurance-quarterly-full" from disk (0 days old).
# Loading "de-income-insurance-quarterly-full" from disk (0 days old).
# Loading "it-income-insurance-quarterly-full" from disk (0 days old).
# Loading "sg-income-insurance-quarterly-full" from disk (0 days old).
# Loading "us-income-insurance-quarterly-full" from disk (0 days old).
# Loading "ca-income-insurance-ttm" from disk (0 days old).
# Loading "de-income-insurance-ttm" from disk (0 days old).
# Loading "it-income-insurance-ttm" from disk (0 days old).
# Loading "sg-income-insurance-ttm" from disk (0 days old).
# Loading "us-income-insurance-ttm" from disk (0 days old).
# Loading "ca-income-insurance-ttm-full" from disk (0 days old).
# Loading "de-income-insurance-ttm-full" from disk (0 days old).
# Loading "it-income-insurance-ttm-full" from disk (0 days old).
# Loading "sg-income-insurance-ttm-full" from disk (0 days old).
# Loading "us-income-insurance-ttm-full" from disk (0 days old).
# Loading "ca-balance-annual" from disk (0 days old).
# Loading "de-balance-annual" from disk (0 days old).
# Loading "it-balance-annual" from disk (0 days old).
# Loading "sg-balance-annual" from disk (0 days old).
# Loading "us-balance-annual" from disk (0 days old).
# Loading "ca-balance-annual-full" from disk (0 days old).
# Loading "de-balance-annual-full" from disk (0 days old).
# Loading "it-balance-annual-full" from disk (0 days old).
# Loading "sg-balance-annual-full" from disk (0 days old).
# Loading "us-balance-annual-full" from disk (0 days old).
# Loading "ca-balance-quarterly" from disk (0 days old).
# Loading "de-balance-quarterly" from disk (0 days old).
# Loading "it-balance-quarterly" from disk (0 days old).
# Loading "sg-balance-quarterly" from disk (0 days old).
# Loading "us-balance-quarterly" from disk (0 days old).
# Loading "ca-balance-quarterly-full" from disk (0 days old).
# Loading "de-balance-quarterly-full" from disk (0 days old).
# Loading "it-balance-quarterly-full" from disk (0 days old).
# Loading "sg-balance-quarterly-full" from disk (0 days old).
# Loading "us-balance-quarterly-full" from disk (0 days old).
# Loading "ca-balance-ttm" from disk (0 days old).
# Loading "de-balance-ttm" from disk (0 days old).
# Loading "it-balance-ttm" from disk (0 days old).
# Loading "sg-balance-ttm" from disk (0 days old).
# Loading "us-balance-ttm" from disk (0 days old).
# Loading "ca-balance-ttm-full" from disk (0 days old).
# Loading "de-balance-ttm-full" from disk (0 days old).
# Loading "it-balance-ttm-full" from disk (0 days old).
# Loading "sg-balance-ttm-full" from disk (0 days old).
# Loading "us-balance-ttm-full" from disk (0 days old).
# Loading "ca-balance-banks-annual" from disk (0 days old).
# Loading "de-balance-banks-annual" from disk (0 days old).
# Loading "it-balance-banks-annual" from disk (0 days old).
# Loading "sg-balance-banks-annual" from disk (0 days old).
# Loading "us-balance-banks-annual" from disk (0 days old).
# Loading "ca-balance-banks-annual-full" from disk (0 days old).
# Loading "de-balance-banks-annual-full" from disk (0 days old).
# Loading "it-balance-banks-annual-full" from disk (0 days old).
# Loading "sg-balance-banks-annual-full" from disk (0 days old).
# Loading "us-balance-banks-annual-full" from disk (0 days old).
# Loading "ca-balance-banks-quarterly" from disk (0 days old).
# Loading "de-balance-banks-quarterly" from disk (0 days old).
# Loading "it-balance-banks-quarterly" from disk (0 days old).
# Loading "sg-balance-banks-quarterly" from disk (0 days old).
# Loading "us-balance-banks-quarterly" from disk (0 days old).
# Loading "ca-balance-banks-quarterly-full" from disk (0 days old).
# Loading "de-balance-banks-quarterly-full" from disk (0 days old).
# Loading "it-balance-banks-quarterly-full" from disk (0 days old).
# Loading "sg-balance-banks-quarterly-full" from disk (0 days old).
# Loading "us-balance-banks-quarterly-full" from disk (0 days old).
# Loading "ca-balance-banks-ttm" from disk (0 days old).
# Loading "de-balance-banks-ttm" from disk (0 days old).
# Loading "it-balance-banks-ttm" from disk (0 days old).
# Loading "sg-balance-banks-ttm" from disk (0 days old).
# Loading "us-balance-banks-ttm" from disk (0 days old).
# Loading "ca-balance-banks-ttm-full" from disk (0 days old).
# Loading "de-balance-banks-ttm-full" from disk (0 days old).
# Loading "it-balance-banks-ttm-full" from disk (0 days old).
# Loading "sg-balance-banks-ttm-full" from disk (0 days old).
# Loading "us-balance-banks-ttm-full" from disk (0 days old).
# Loading "ca-balance-insurance-annual" from disk (0 days old).
# Loading "de-balance-insurance-annual" from disk (0 days old).
# Loading "it-balance-insurance-annual" from disk (0 days old).
# Loading "sg-balance-insurance-annual" from disk (0 days old).
# Loading "us-balance-insurance-annual" from disk (0 days old).
# Loading "ca-balance-insurance-annual-full" from disk (0 days old).
# Loading "de-balance-insurance-annual-full" from disk (0 days old).
# Loading "it-balance-insurance-annual-full" from disk (0 days old).
# Loading "sg-balance-insurance-annual-full" from disk (0 days old).
# Loading "us-balance-insurance-annual-full" from disk (0 days old).
# Loading "ca-balance-insurance-quarterly" from disk (0 days old).
# Loading "de-balance-insurance-quarterly" from disk (0 days old).
# Loading "it-balance-insurance-quarterly" from disk (0 days old).
# Loading "sg-balance-insurance-quarterly" from disk (0 days old).
# Loading "us-balance-insurance-quarterly" from disk (0 days old).
# Loading "ca-balance-insurance-quarterly-full" from disk (0 days old).
# Loading "de-balance-insurance-quarterly-full" from disk (0 days old).
# Loading "it-balance-insurance-quarterly-full" from disk (0 days old).
# Loading "sg-balance-insurance-quarterly-full" from disk (0 days old).
# Loading "us-balance-insurance-quarterly-full" from disk (0 days old).
# Loading "ca-balance-insurance-ttm" from disk (0 days old).
# Loading "de-balance-insurance-ttm" from disk (0 days old).
# Loading "it-balance-insurance-ttm" from disk (0 days old).
# Loading "sg-balance-insurance-ttm" from disk (0 days old).
# Loading "us-balance-insurance-ttm" from disk (0 days old).
# Loading "ca-balance-insurance-ttm-full" from disk (0 days old).
# Loading "de-balance-insurance-ttm-full" from disk (0 days old).
# Loading "it-balance-insurance-ttm-full" from disk (0 days old).
# Loading "sg-balance-insurance-ttm-full" from disk (0 days old).
# Loading "us-balance-insurance-ttm-full" from disk (0 days old).
# Loading "ca-cashflow-annual" from disk (0 days old).
# Loading "de-cashflow-annual" from disk (0 days old).
# Loading "it-cashflow-annual" from disk (0 days old).
# Loading "sg-cashflow-annual" from disk (0 days old).
# Loading "us-cashflow-annual" from disk (0 days old).
# Loading "ca-cashflow-annual-full" from disk (0 days old).
# Loading "de-cashflow-annual-full" from disk (0 days old).
# Loading "it-cashflow-annual-full" from disk (0 days old).
# Loading "sg-cashflow-annual-full" from disk (0 days old).
# Loading "us-cashflow-annual-full" from disk (0 days old).
# Loading "ca-cashflow-quarterly" from disk (0 days old).
# Loading "de-cashflow-quarterly" from disk (0 days old).
# Loading "it-cashflow-quarterly" from disk (0 days old).
# Loading "sg-cashflow-quarterly" from disk (0 days old).
# Loading "us-cashflow-quarterly" from disk (0 days old).
# Loading "ca-cashflow-quarterly-full" from disk (0 days old).
# Loading "de-cashflow-quarterly-full" from disk (0 days old).
# Loading "it-cashflow-quarterly-full" from disk (0 days old).
# Loading "sg-cashflow-quarterly-full" from disk (0 days old).
# Loading "us-cashflow-quarterly-full" from disk (0 days old).
# Loading "ca-cashflow-ttm" from disk (0 days old).
# Loading "de-cashflow-ttm" from disk (0 days old).
# Loading "it-cashflow-ttm" from disk (0 days old).
# Loading "sg-cashflow-ttm" from disk (0 days old).
# Loading "us-cashflow-ttm" from disk (0 days old).
# Loading "ca-cashflow-ttm-full" from disk (0 days old).
# Loading "de-cashflow-ttm-full" from disk (0 days old).
# Loading "it-cashflow-ttm-full" from disk (0 days old).
# Loading "sg-cashflow-ttm-full" from disk (0 days old).
# Loading "us-cashflow-ttm-full" from disk (0 days old).
# Loading "ca-cashflow-banks-annual" from disk (0 days old).
# Loading "de-cashflow-banks-annual" from disk (0 days old).
# Loading "it-cashflow-banks-annual" from disk (0 days old).
# Loading "sg-cashflow-banks-annual" from disk (0 days old).
# Loading "us-cashflow-banks-annual" from disk (0 days old).
# Loading "ca-cashflow-banks-annual-full" from disk (0 days old).
# Loading "de-cashflow-banks-annual-full" from disk (0 days old).
# Loading "it-cashflow-banks-annual-full" from disk (0 days old).
# Loading "sg-cashflow-banks-annual-full" from disk (0 days old).
# Loading "us-cashflow-banks-annual-full" from disk (0 days old).
# Loading "ca-cashflow-banks-quarterly" from disk (0 days old).
# Loading "de-cashflow-banks-quarterly" from disk (0 days old).
# Loading "it-cashflow-banks-quarterly" from disk (0 days old).
# Loading "sg-cashflow-banks-quarterly" from disk (0 days old).
# Loading "us-cashflow-banks-quarterly" from disk (0 days old).
# Loading "ca-cashflow-banks-quarterly-full" from disk (0 days old).
# Loading "de-cashflow-banks-quarterly-full" from disk (0 days old).
# Loading "it-cashflow-banks-quarterly-full" from disk (0 days old).
# Loading "sg-cashflow-banks-quarterly-full" from disk (0 days old).
# Loading "us-cashflow-banks-quarterly-full" from disk (0 days old).
# Loading "ca-cashflow-banks-ttm" from disk (0 days old).
# Loading "de-cashflow-banks-ttm" from disk (0 days old).
# Loading "it-cashflow-banks-ttm" from disk (0 days old).
# Loading "sg-cashflow-banks-ttm" from disk (0 days old).
# Loading "us-cashflow-banks-ttm" from disk (0 days old).
# Loading "ca-cashflow-banks-ttm-full" from disk (0 days old).
# Loading "de-cashflow-banks-ttm-full" from disk (0 days old).
# Loading "it-cashflow-banks-ttm-full" from disk (0 days old).
# Loading "sg-cashflow-banks-ttm-full" from disk (0 days old).
# Loading "us-cashflow-banks-ttm-full" from disk (0 days old).
# Loading "ca-cashflow-insurance-annual" from disk (0 days old).
# Loading "de-cashflow-insurance-annual" from disk (0 days old).
# Loading "it-cashflow-insurance-annual" from disk (0 days old).
# Loading "sg-cashflow-insurance-annual" from disk (0 days old).
# Loading "us-cashflow-insurance-annual" from disk (0 days old).
# Loading "ca-cashflow-insurance-annual-full" from disk (0 days old).
# Loading "de-cashflow-insurance-annual-full" from disk (0 days old).
# Loading "it-cashflow-insurance-annual-full" from disk (0 days old).
# Loading "sg-cashflow-insurance-annual-full" from disk (0 days old).
# Loading "us-cashflow-insurance-annual-full" from disk (0 days old).
# Loading "ca-cashflow-insurance-quarterly" from disk (0 days old).
# Loading "de-cashflow-insurance-quarterly" from disk (0 days old).
# Loading "it-cashflow-insurance-quarterly" from disk (0 days old).
# Loading "sg-cashflow-insurance-quarterly" from disk (0 days old).
# Loading "us-cashflow-insurance-quarterly" from disk (0 days old).
# Loading "ca-cashflow-insurance-quarterly-full" from disk (0 days old).
# Loading "de-cashflow-insurance-quarterly-full" from disk (0 days old).
# Loading "it-cashflow-insurance-quarterly-full" from disk (0 days old).
# Loading "sg-cashflow-insurance-quarterly-full" from disk (0 days old).
# Loading "us-cashflow-insurance-quarterly-full" from disk (0 days old).
# Loading "ca-cashflow-insurance-ttm" from disk (0 days old).
# Loading "de-cashflow-insurance-ttm" from disk (0 days old).
# Loading "it-cashflow-insurance-ttm" from disk (0 days old).
# Loading "sg-cashflow-insurance-ttm" from disk (0 days old).
# Loading "us-cashflow-insurance-ttm" from disk (0 days old).
# Loading "ca-cashflow-insurance-ttm-full" from disk (0 days old).
# Loading "de-cashflow-insurance-ttm-full" from disk (0 days old).
# Loading "it-cashflow-insurance-ttm-full" from disk (0 days old).
# Loading "sg-cashflow-insurance-ttm-full" from disk (0 days old).
# Loading "us-cashflow-insurance-ttm-full" from disk (0 days old).
# Loading "ca-shareprices-latest" from disk (0 days old).
# Loading "de-shareprices-latest" from disk (0 days old).
# Loading "it-shareprices-latest" from disk (0 days old).
# Loading "sg-shareprices-latest" from disk (0 days old).
# Loading "us-shareprices-latest" from disk (0 days old).
# Loading "ca-shareprices-daily" from disk (0 days old).
# Loading "de-shareprices-daily" from disk (0 days old).
# Loading "it-shareprices-daily" from disk (0 days old).
# Loading "sg-shareprices-daily" from disk (0 days old).
# Loading "us-shareprices-daily" from disk (0 days old).
# Loading "ca-companies" from disk (0 days old).
# Loading "de-companies" from disk (0 days old).
# Loading "it-companies" from disk (0 days old).
# Loading "sg-companies" from disk (0 days old).
# Loading "us-companies" from disk (0 days old).
# Loading "industries" from disk (0 days old).
# Loading "markets" from disk (0 days old).
# CPU times: user 9.44 s, sys: 871 ms, total: 10.3 s
# Wall time: 10.4 s

# %%
# Example for annual Income Statements.
data.get(dataset='income', variant='annual', market='us').head()
# Out:
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0   GOOG        18      USD         2016            FY  2016-12-31
# 1   GOOG        18      USD         2015            FY  2015-12-31
# 2   GOOG        18      USD         2014            FY  2014-12-31
# 3   GOOG        18      USD         2013            FY  2013-12-31
# 4   GOOG        18      USD         2017            FY  2017-12-31
#
#   Publish Date  Shares (Basic)  Shares (Diluted)       Revenue  ...  \
# 0   2017-02-03     687778000.0       747565000.0  9.027200e+10  ...
# 1   2016-02-11     684626000.0       744675000.0  7.498900e+10  ...
# 2   2015-10-29     675935000.0       741998000.0  6.600100e+10  ...
# 3   2015-10-29     665692000.0       736950000.0  5.551900e+10  ...
# 4   2018-02-06     692901000.0       750730000.0  1.108550e+11  ...
#
#    Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                 4.340000e+08                    NaN
# 1                 2.910000e+08                    NaN
# 2                 7.630000e+08                    NaN
# 3                 4.960000e+08                    NaN
# 4                 1.047000e+09                    NaN
#
#    Pretax Income (Loss), Adjusted  Abnormal Gains (Losses)  \
# 0                     24150000000                      NaN
# 1                     19651000000                      NaN
# 2                     17259000000                      NaN
# 3                     15899000000                      NaN
# 4                     29929000000            -2.736000e+09
#
#    Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 0           24150000000                      -4.672000e+09
# 1           19651000000                      -3.303000e+09
# 2           17259000000                      -3.639000e+09
# 3           15899000000                      -2.739000e+09
# 4           27193000000                      -1.453100e+10
#
#    Income (Loss) From Continuing Operations  Net Extraordinary Gains (Losses)  \
# 0                               19478000000                               0.0
# 1                               16348000000                               0.0
# 2                               13620000000                       516000000.0
# 3                               13160000000                      -427000000.0
# 4                               12662000000                               NaN
#
#     Net Income  Net Income Available to Common Shareholders
# 0  19478000000                                  19478000000
# 1  16348000000                                  15826000000
# 2  14136000000                                  14136000000
# 3  12733000000                                  12733000000
# 4  12662000000                                  12662000000
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Function for Testing Datasets

# %%
def test_datasets(test_name, datasets=None, variants=None,
                  markets=None,
                  test_func=None, test_func_rows=None,
                  process_df_none=False, raise_exception=True):
    """
    Helper-function for running tests on many Pandas DataFrames.
    
    :param test_name:
        String with the name of the test.
        
    :param datasets:
        By default (datasets=None) all possible datasets
        will be tested. Otherwise datasets is a list of
        strings with dataset names to be tested.
        
    :param variants:
        By default (variants=None) all possible variants
        for each dataset will be tested, as defined in
        simfin.datasets.valid_variants. Otherwise variants
        is a list of strings and only those variants
        will be tested.
        
    :param markets:
        By default (markets=None) all possible markets
        for each dataset will be tested, as defined in
        simfin.datasets.valid_markets. Otherwise markets
        is a list of strings and only those markets
        will be tested.
        
    :param test_func:
        Function to be called on the Pandas DataFrame for
        each dataset. If there are problems with the DataFrame
        then return True, otherwise return False.
        
        This is generally used for testing problems with the
        entire DataFrame. For example, if the dataset is empty:

        test_func = lambda df: len(df) == 0
        
        If this returns True then there is a problem with df.
                
    :param test_func_rows:
        Similar to test_func but for testing individual rows
        of a DataFrame. For example, test if SHARES_BASIC is
        None, zero or negative:
        
        test_func_rows = lambda df: (df[SHARES_BASIC] is None or
                                     df[SHARES_BASIC] <= 0)

    :param process_df_none:
        Boolean whether to process (True) or skip (False)
        DataFrames that are None, because they could not be loaded.

    :param raise_exception:
        Boolean. If True then raise an exception if there were
        any problems, but wait until all datasets have been
        tested, so we can print the list of datasets with problems.
        
    :return:
        None
    """
    
    # Convert test_func_rows to test_func.
    if test_func_rows is not None:
        test_func = lambda df: test_func_rows(df).any()

    # Number of problems found.
    num_problems = 0

    # For all datasets, variants and markets.
    for dataset, variant, market, df in data.iter(datasets=datasets,
                                                  variants=variants,
                                                  markets=markets):
        # Also process DataFrames that are None,
        # because they could not be loaded?
        if df is not None or process_df_none:
            try:
                # Perform the user-supplied test.
                problem_found = test_func(df)
            except:
                # An exception occurred so we consider
                # that to be a problem.
                problem_found = True
                
            if problem_found:
                # Increase the number of problems found.
                num_problems += 1

                # Print the test's name. Only done once.
                if num_problems==1:
                    print(test_name, file=sys.stderr)

                # Print the dataset details.
                msg = "dataset='{}', variant='{}', market='{}'"
                msg = msg.format(dataset, variant, market)
                print(msg, file=sys.stderr)
                
    # Raise exception?
    if num_problems>0 and raise_exception:
        raise Exception(test_name)

# %% [markdown]
# ## Function for Getting Rows with Problems
#
# When a test has found problems in a dataset, it does not show which specific rows have the problem. You can get all the problematic rows using this function:

# %%
def get_problem_rows(df, test_func_rows):
    """
    Perform the given test on all rows of the given DataFrame
    and return a DataFrame with only the problematic rows.
    
    :param df:
        Pandas DataFrame.

    :param test_func_rows:
        Function used for testing each row. This takes
        a Pandas DataFrame as an argument and returns
        a Pandas Series of booleans whether each row
        in the original DataFrame has the error.
        
        For example:
        
        test_func_rows = lambda df: (df[SHARES_BASIC] is None or
                                     df[SHARES_BASIC] <= 0)

    :return:
        Pandas DataFrame with only the problematic rows.
    """

    # Index of the rows with problems.
    idx = test_func_rows(df)
    
    # Extract the rows with problems.
    df2 = df[idx]
    
    return df2

# %% [markdown]
# ## Function for Testing Equality with Tolerance
#
# This function is useful when comparing floating point numbers, or when comparing accounting numbers that are supposed to have a strict relationship (e.g. Assets = Liabilities + Equity) but we might tolerate a small degree of error in the data e.g. 1%.

# %%
def isclose(x, y, tolerance=0.01):
    """
    Compare whether x and y are approximately equal within
    the given tolerance, which is a ratio so tolerance=0.01
    means that we tolerate max 1% difference between x and y.
    
    This is similar to numpy.isclose() but is a more efficient
    implementation for Pandas which apparently does not have
    this built-in already (v. 0.25.1)
    
    :param x:
        Pandas DataFrame or Series.

    :param y:
        Pandas DataFrame or Series.

    :param tolerance:
        Max allowed difference as a ratio e.g. 0.01 = 1%.

    :return:
        Pandas DataFrame or Series with booleans whether
        x and y are approx. equal.
    """
    return (x-y).abs() <= tolerance * y.abs()

# %% [markdown]
# # Tests

# %% [markdown]
# ## Dataset could not be loaded

# %%
test_name = "Dataset could not be loaded"
test_func = lambda df: df is None
test_datasets(datasets=datasets_all,
              test_name=test_name, test_func=test_func,
              process_df_none=True)

# %% [markdown]
# ## Dataset is empty

# %%
test_name = "Dataset is empty"
test_func = lambda df: len(df) == 0
test_datasets(datasets=datasets_all,
              test_name=test_name, test_func=test_func)
# Out:
# Dataset is empty
# dataset='income', variant='annual', market='ca'
# dataset='income', variant='annual', market='it'
# dataset='income', variant='annual-full', market='ca'
# dataset='income', variant='annual-full', market='it'
# dataset='income', variant='quarterly', market='ca'
# dataset='income', variant='quarterly', market='it'
# dataset='income', variant='quarterly-full', market='ca'
# dataset='income', variant='quarterly-full', market='it'
# dataset='income', variant='ttm', market='ca'
# dataset='income', variant='ttm', market='it'
# dataset='income', variant='ttm-full', market='ca'
# dataset='income', variant='ttm-full', market='it'
# dataset='income-banks', variant='annual', market='ca'
# dataset='income-banks', variant='annual', market='it'
# dataset='income-banks', variant='annual', market='sg'
# dataset='income-banks', variant='annual-full', market='ca'
# dataset='income-banks', variant='annual-full', market='it'
# dataset='income-banks', variant='annual-full', market='sg'
# dataset='income-banks', variant='quarterly', market='ca'
# dataset='income-banks', variant='quarterly', market='it'
# dataset='income-banks', variant='quarterly', market='sg'
# dataset='income-banks', variant='quarterly-full', market='ca'
# dataset='income-banks', variant='quarterly-full', market='it'
# dataset='income-banks', variant='quarterly-full', market='sg'
# dataset='income-banks', variant='ttm', market='ca'
# dataset='income-banks', variant='ttm', market='it'
# dataset='income-banks', variant='ttm', market='sg'
# dataset='income-banks', variant='ttm-full', market='ca'
# dataset='income-banks', variant='ttm-full', market='it'
# dataset='income-banks', variant='ttm-full', market='sg'
# dataset='income-insurance', variant='annual', market='ca'
# dataset='income-insurance', variant='annual', market='de'
# dataset='income-insurance', variant='annual', market='it'
# dataset='income-insurance', variant='annual', market='sg'
# dataset='income-insurance', variant='annual-full', market='ca'
# dataset='income-insurance', variant='annual-full', market='de'
# dataset='income-insurance', variant='annual-full', market='it'
# dataset='income-insurance', variant='annual-full', market='sg'
# dataset='income-insurance', variant='quarterly', market='ca'
# dataset='income-insurance', variant='quarterly', market='de'
# dataset='income-insurance', variant='quarterly', market='it'
# dataset='income-insurance', variant='quarterly', market='sg'
# dataset='income-insurance', variant='quarterly-full', market='ca'
# dataset='income-insurance', variant='quarterly-full', market='de'
# dataset='income-insurance', variant='quarterly-full', market='it'
# dataset='income-insurance', variant='quarterly-full', market='sg'
# dataset='income-insurance', variant='ttm', market='ca'
# dataset='income-insurance', variant='ttm', market='de'
# dataset='income-insurance', variant='ttm', market='it'
# dataset='income-insurance', variant='ttm', market='sg'
# dataset='income-insurance', variant='ttm-full', market='ca'
# dataset='income-insurance', variant='ttm-full', market='de'
# dataset='income-insurance', variant='ttm-full', market='it'
# dataset='income-insurance', variant='ttm-full', market='sg'
# dataset='balance', variant='annual', market='ca'
# dataset='balance', variant='annual', market='it'
# dataset='balance', variant='annual', market='sg'
# dataset='balance', variant='annual-full', market='ca'
# dataset='balance', variant='annual-full', market='it'
# dataset='balance', variant='annual-full', market='sg'
# dataset='balance', variant='quarterly', market='ca'
# dataset='balance', variant='quarterly', market='it'
# dataset='balance', variant='quarterly', market='sg'
# dataset='balance', variant='quarterly-full', market='ca'
# dataset='balance', variant='quarterly-full', market='it'
# dataset='balance', variant='quarterly-full', market='sg'
# dataset='balance', variant='ttm', market='ca'
# dataset='balance', variant='ttm', market='it'
# dataset='balance', variant='ttm', market='sg'
# dataset='balance', variant='ttm-full', market='ca'
# dataset='balance', variant='ttm-full', market='it'
# dataset='balance', variant='ttm-full', market='sg'
# dataset='balance-banks', variant='annual', market='ca'
# dataset='balance-banks', variant='annual', market='it'
# dataset='balance-banks', variant='annual', market='sg'
# dataset='balance-banks', variant='annual-full', market='ca'
# dataset='balance-banks', variant='annual-full', market='it'
# dataset='balance-banks', variant='annual-full', market='sg'
# dataset='balance-banks', variant='quarterly', market='ca'
# dataset='balance-banks', variant='quarterly', market='it'
# dataset='balance-banks', variant='quarterly', market='sg'
# dataset='balance-banks', variant='quarterly-full', market='ca'
# dataset='balance-banks', variant='quarterly-full', market='it'
# dataset='balance-banks', variant='quarterly-full', market='sg'
# dataset='balance-banks', variant='ttm', market='ca'
# dataset='balance-banks', variant='ttm', market='it'
# dataset='balance-banks', variant='ttm', market='sg'
# dataset='balance-banks', variant='ttm-full', market='ca'
# dataset='balance-banks', variant='ttm-full', market='it'
# dataset='balance-banks', variant='ttm-full', market='sg'
# dataset='balance-insurance', variant='annual', market='ca'
# dataset='balance-insurance', variant='annual', market='de'
# dataset='balance-insurance', variant='annual', market='it'
# dataset='balance-insurance', variant='annual', market='sg'
# dataset='balance-insurance', variant='annual-full', market='ca'
# dataset='balance-insurance', variant='annual-full', market='de'
# dataset='balance-insurance', variant='annual-full', market='it'
# dataset='balance-insurance', variant='annual-full', market='sg'
# dataset='balance-insurance', variant='quarterly', market='ca'
# dataset='balance-insurance', variant='quarterly', market='de'
# dataset='balance-insurance', variant='quarterly', market='it'
# dataset='balance-insurance', variant='quarterly', market='sg'
# dataset='balance-insurance', variant='quarterly-full', market='ca'
# dataset='balance-insurance', variant='quarterly-full', market='de'
# dataset='balance-insurance', variant='quarterly-full', market='it'
# dataset='balance-insurance', variant='quarterly-full', market='sg'
# dataset='balance-insurance', variant='ttm', market='ca'
# dataset='balance-insurance', variant='ttm', market='de'
# dataset='balance-insurance', variant='ttm', market='it'
# dataset='balance-insurance', variant='ttm', market='sg'
# dataset='balance-insurance', variant='ttm-full', market='ca'
# dataset='balance-insurance', variant='ttm-full', market='de'
# dataset='balance-insurance', variant='ttm-full', market='it'
# dataset='balance-insurance', variant='ttm-full', market='sg'
# dataset='cashflow', variant='annual', market='ca'
# dataset='cashflow', variant='annual', market='it'
# dataset='cashflow', variant='annual', market='sg'
# dataset='cashflow', variant='annual-full', market='ca'
# dataset='cashflow', variant='annual-full', market='it'
# dataset='cashflow', variant='annual-full', market='sg'
# dataset='cashflow', variant='quarterly', market='ca'
# dataset='cashflow', variant='quarterly', market='it'
# dataset='cashflow', variant='quarterly', market='sg'
# dataset='cashflow', variant='quarterly-full', market='ca'
# dataset='cashflow', variant='quarterly-full', market='it'
# dataset='cashflow', variant='quarterly-full', market='sg'
# dataset='cashflow', variant='ttm', market='ca'
# dataset='cashflow', variant='ttm', market='it'
# dataset='cashflow', variant='ttm', market='sg'
# dataset='cashflow', variant='ttm-full', market='ca'
# dataset='cashflow', variant='ttm-full', market='it'
# dataset='cashflow', variant='ttm-full', market='sg'
# dataset='cashflow-banks', variant='annual', market='ca'
# dataset='cashflow-banks', variant='annual', market='it'
# dataset='cashflow-banks', variant='annual', market='sg'
# dataset='cashflow-banks', variant='annual-full', market='ca'
# dataset='cashflow-banks', variant='annual-full', market='it'
# dataset='cashflow-banks', variant='annual-full', market='sg'
# dataset='cashflow-banks', variant='quarterly', market='ca'
# dataset='cashflow-banks', variant='quarterly', market='it'
# dataset='cashflow-banks', variant='quarterly', market='sg'
# dataset='cashflow-banks', variant='quarterly-full', market='ca'
# dataset='cashflow-banks', variant='quarterly-full', market='it'
# dataset='cashflow-banks', variant='quarterly-full', market='sg'
# dataset='cashflow-banks', variant='ttm', market='ca'
# dataset='cashflow-banks', variant='ttm', market='it'
# dataset='cashflow-banks', variant='ttm', market='sg'
# dataset='cashflow-banks', variant='ttm-full', market='ca'
# dataset='cashflow-banks', variant='ttm-full', market='it'
# dataset='cashflow-banks', variant='ttm-full', market='sg'
# dataset='cashflow-insurance', variant='annual', market='ca'
# dataset='cashflow-insurance', variant='annual', market='de'
# dataset='cashflow-insurance', variant='annual', market='it'
# dataset='cashflow-insurance', variant='annual', market='sg'
# dataset='cashflow-insurance', variant='annual-full', market='ca'
# dataset='cashflow-insurance', variant='annual-full', market='de'
# dataset='cashflow-insurance', variant='annual-full', market='it'
# dataset='cashflow-insurance', variant='annual-full', market='sg'
# dataset='cashflow-insurance', variant='quarterly', market='ca'
# dataset='cashflow-insurance', variant='quarterly', market='de'
# dataset='cashflow-insurance', variant='quarterly', market='it'
# dataset='cashflow-insurance', variant='quarterly', market='sg'
# dataset='cashflow-insurance', variant='quarterly-full', market='ca'
# dataset='cashflow-insurance', variant='quarterly-full', market='de'
# dataset='cashflow-insurance', variant='quarterly-full', market='it'
# dataset='cashflow-insurance', variant='quarterly-full', market='sg'
# dataset='cashflow-insurance', variant='ttm', market='ca'
# dataset='cashflow-insurance', variant='ttm', market='de'
# dataset='cashflow-insurance', variant='ttm', market='it'
# dataset='cashflow-insurance', variant='ttm', market='sg'
# dataset='cashflow-insurance', variant='ttm-full', market='ca'
# dataset='cashflow-insurance', variant='ttm-full', market='de'
# dataset='cashflow-insurance', variant='ttm-full', market='it'
# dataset='cashflow-insurance', variant='ttm-full', market='sg'
# dataset='shareprices', variant='latest', market='ca'
# dataset='shareprices', variant='latest', market='it'
# dataset='shareprices', variant='daily', market='ca'
# dataset='shareprices', variant='daily', market='it'
# dataset='companies', variant='None', market='ca'
# dataset='companies', variant='None', market='it'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-eddf8cc4f8f4> in <module>
#       2 test_func = lambda df: len(df) == 0
#       3 test_datasets(datasets=datasets_all,
# ----> 4               test_name=test_name, test_func=test_func)
#
# <ipython-input-7-b3d44117203b> in test_datasets(test_name, datasets, variants, markets, test_func, test_func_rows, process_df_none, raise_exception)
#      98     # Raise exception?
#      99     if num_problems>0 and raise_exception:
# --> 100         raise Exception(test_name)
#
# Exception: Dataset is empty

# %%
data.get(dataset='shareprices', variant='daily', market='ca')
# Out:
# Empty DataFrame
# Columns: [Ticker, SimFinId, Date, Open, Low, High, Close, Adj. Close, Dividend, Volume]
# Index: []

# %% [markdown]
# ## Shares Basic is None or <= 0

# %%
test_name = "SHARES_BASIC is None or <= 0"
test_func_rows = lambda df: (df[SHARES_BASIC] is None or
                             df[SHARES_BASIC] <= 0)
test_datasets(datasets=datasets_fundamental,
              test_name=test_name, test_func_rows=test_func_rows)
# Out:
# SHARES_BASIC is None or <= 0
# dataset='income', variant='annual', market='us'
# dataset='income', variant='annual-full', market='us'
# dataset='income', variant='quarterly', market='us'
# dataset='income', variant='quarterly-full', market='us'
# dataset='income', variant='ttm', market='us'
# dataset='income', variant='ttm-full', market='us'
# dataset='income-banks', variant='quarterly', market='us'
# dataset='income-banks', variant='quarterly-full', market='us'
# dataset='income-banks', variant='ttm', market='us'
# dataset='income-banks', variant='ttm-full', market='us'
# dataset='income-insurance', variant='quarterly', market='us'
# dataset='income-insurance', variant='quarterly-full', market='us'
# dataset='income-insurance', variant='ttm', market='us'
# dataset='income-insurance', variant='ttm-full', market='us'
# dataset='balance', variant='annual', market='us'
# dataset='balance', variant='annual-full', market='us'
# dataset='balance', variant='quarterly', market='us'
# dataset='balance', variant='quarterly-full', market='us'
# dataset='balance', variant='ttm', market='us'
# dataset='balance', variant='ttm-full', market='us'
# dataset='balance-banks', variant='annual', market='us'
# dataset='balance-banks', variant='annual-full', market='us'
# dataset='balance-banks', variant='quarterly', market='us'
# dataset='balance-banks', variant='quarterly-full', market='us'
# dataset='balance-banks', variant='ttm', market='us'
# dataset='balance-banks', variant='ttm-full', market='us'
# dataset='balance-insurance', variant='annual', market='us'
# dataset='balance-insurance', variant='annual-full', market='us'
# dataset='balance-insurance', variant='quarterly', market='us'
# dataset='balance-insurance', variant='quarterly-full', market='us'
# dataset='balance-insurance', variant='ttm', market='us'
# dataset='balance-insurance', variant='ttm-full', market='us'
# dataset='cashflow', variant='annual', market='us'
# dataset='cashflow', variant='annual-full', market='us'
# dataset='cashflow', variant='quarterly', market='us'
# dataset='cashflow', variant='quarterly-full', market='us'
# dataset='cashflow', variant='ttm', market='us'
# dataset='cashflow', variant='ttm-full', market='us'
# dataset='cashflow-banks', variant='quarterly', market='us'
# dataset='cashflow-banks', variant='quarterly-full', market='us'
# dataset='cashflow-banks', variant='ttm', market='us'
# dataset='cashflow-banks', variant='ttm-full', market='us'
# dataset='cashflow-insurance', variant='quarterly', market='us'
# dataset='cashflow-insurance', variant='quarterly-full', market='us'
# dataset='cashflow-insurance', variant='ttm', market='us'
# dataset='cashflow-insurance', variant='ttm-full', market='us'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-17-2b31ba1b5cec> in <module>
#       3                              df[SHARES_BASIC] <= 0)
#       4 test_datasets(datasets=datasets_fundamental,
# ----> 5               test_name=test_name, test_func_rows=test_func_rows)
#
# <ipython-input-7-b3d44117203b> in test_datasets(test_name, datasets, variants, markets, test_func, test_func_rows, process_df_none, raise_exception)
#      98     # Raise exception?
#      99     if num_problems>0 and raise_exception:
# --> 100         raise Exception(test_name)
#
# Exception: SHARES_BASIC is None or <= 0

# %%
# Show the problematic rows for a dataset.
df = data.get(dataset='income', variant='annual', market='us')
get_problem_rows(df=df, test_func_rows=test_func_rows)
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 1221     AAL     68568      USD         2010            FY  2010-12-31
# 1222     AAL     68568      USD         2009            FY  2009-12-31
# 8144     SPB    357600      USD         2017            FY  2017-09-30
# 8145     SPB    357600      USD         2016            FY  2016-09-30
# 8146     SPB    357600      USD         2015            FY  2015-09-30
# 8147     SPB    357600      USD         2014            FY  2014-09-30
# 8148     SPB    357600      USD         2013            FY  2013-09-30
# 8149     SPB    357600      USD         2012            FY  2012-09-30
# 8150     SPB    357600      USD         2011            FY  2011-09-30
# 8151     SPB    357600      USD         2010            FY  2010-09-30
# 8770    CHTR    378110      USD         2015            FY  2015-12-31
# 8771    CHTR    378110      USD         2014            FY  2014-12-31
# 8772    CHTR    378110      USD         2013            FY  2013-12-31
# 8773    CHTR    378110      USD         2012            FY  2012-12-31
# 8774    CHTR    378110      USD         2011            FY  2011-12-31
# 8775    CHTR    378110      USD         2010            FY  2010-12-31
# 13729   MMEG    659865      USD         2016            FY  2016-12-31
# 13730   MMEG    659865      USD         2015            FY  2015-12-31
# 13731   MMEG    659865      USD         2014            FY  2014-12-31
# 13732   MMEG    659865      USD         2013            FY  2013-12-31
# 13785   MFST    662704      USD         2017            FY  2017-12-31
# 13786   MFST    662704      USD         2016            FY  2016-12-31
# 13787   MFST    662704      USD         2015            FY  2015-12-31
# 13788   MFST    662704      USD         2014            FY  2014-12-31
# 13789   MFST    662704      USD         2013            FY  2013-12-31
# 13790   MFST    662704      USD         2012            FY  2012-12-31
# 13791   MFST    662704      USD         2011            FY  2011-12-31
# 14554   HMNY    698616      USD         2016            FY  2016-12-31
# 14809   CNXS    706380      USD         2013            FY  2013-06-30
#
#       Publish Date  Shares (Basic)  Shares (Diluted)       Revenue  ...  \
# 1221    2011-02-16             0.0               0.0  2.217000e+10  ...
# 1222    2010-07-21             0.0               0.0  1.991700e+10  ...
# 8144    2017-11-17             0.0               0.0  5.007400e+09  ...
# 8145    2016-08-03             0.0               0.0  5.039700e+09  ...
# 8146    2015-08-06             0.0               0.0  4.690400e+09  ...
# 8147    2014-08-06             0.0               0.0  4.429100e+09  ...
# 8148    2013-08-08             0.0               0.0  4.085600e+09  ...
# 8149    2012-08-07             0.0               0.0  3.252435e+09  ...
# 8150    2011-08-11             0.0               0.0  3.154466e+09  ...
# 8151    2011-08-11             0.0               0.0  2.567011e+09  ...
# 8770    2016-02-10             0.0               0.0  9.754000e+09  ...
# 8771    2015-02-24             0.0               0.0  9.108000e+09  ...
# 8772    2014-02-21             0.0               0.0  8.155000e+09  ...
# 8773    2013-02-22             0.0               0.0  7.504000e+09  ...
# 8774    2012-02-27             0.0               0.0  7.204000e+09  ...
# 8775    2011-05-03             0.0               0.0  7.059000e+09  ...
# 13729   2017-04-13             0.0               0.0  2.501000e+03  ...
# 13730   2016-04-11             0.0               0.0  5.660000e+02  ...
# 13731   2015-03-31             0.0               0.0  6.760000e+02  ...
# 13732   2014-11-14             0.0               0.0  7.915000e+03  ...
# 13785   2018-04-12             0.0               0.0  2.999500e+04  ...
# 13786   2017-04-06             0.0               0.0  0.000000e+00  ...
# 13787   2016-04-14             0.0               0.0  1.858000e+03  ...
# 13788   2015-04-15             0.0               0.0  8.562700e+04  ...
# 13789   2014-04-15             0.0               0.0  5.449700e+04  ...
# 13790   2013-04-01             0.0               0.0  0.000000e+00  ...
# 13791   2012-09-05             0.0               0.0  4.425900e+04  ...
# 14554   2017-04-14             0.0               0.0  6.759700e+06  ...
# 14809   2014-06-02             0.0               0.0  0.000000e+00  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 1221                 -8.140000e+08          -7.970000e+08
# 1222                 -7.480000e+08          -7.100000e+08
# 8144                 -2.168000e+08          -2.111000e+08
# 8145                 -2.586000e+08          -2.500000e+08
# 8146                 -2.808000e+08          -2.719000e+08
# 8147                 -2.084000e+08          -2.021000e+08
# 8148                 -3.791000e+08          -3.756000e+08
# 8149                 -1.927890e+08          -1.919110e+08
# 8150                 -2.108200e+08          -2.083290e+08
# 8151                 -2.893150e+08          -2.770150e+08
# 8770                 -1.313000e+09          -1.306000e+09
# 8771                 -9.110000e+08          -9.110000e+08
# 8772                 -8.460000e+08          -8.460000e+08
# 8773                 -9.070000e+08          -9.070000e+08
# 8774                 -9.680000e+08          -9.630000e+08
# 8775                 -8.810000e+08          -8.770000e+08
# 13729                -8.417990e+05          -8.417990e+05
# 13730                -1.121100e+04          -1.121100e+04
# 13731                -7.354000e+03          -7.354000e+03
# 13732                 0.000000e+00           0.000000e+00
# 13785                -5.011560e+05          -4.051440e+05
# 13786                -6.837690e+05          -6.418110e+05
# 13787                -1.117030e+05          -9.251500e+04
# 13788                -1.754700e+04          -1.654000e+03
# 13789                -1.488000e+03          -1.488000e+03
# 13790                -1.656000e+03          -1.656000e+03
# 13791                -5.900000e+01          -5.900000e+01
# 14554                -5.192152e+06          -5.192152e+06
# 14809                -3.175320e+05          -3.175320e+05
#
#        Pretax Income (Loss), Adjusted  Abnormal Gains (Losses)  \
# 1221                       -506000000                      0.0
# 1222                      -1752000000                      NaN
# 8144                        426000000              -81400000.0
# 8145                        453700000              -56100000.0
# 8146                        278700000              -85400000.0
# 8147                        312800000              -39300000.0
# 8148                         20500000              -48400000.0
# 8149                        140023000              -31066000.0
# 8150                         53727000              -36603000.0
# 8151                        -82085000              -42098000.0
# 8770                       -199000000             -132000000.0
# 8771                         60000000               -7000000.0
# 8772                         63000000             -112000000.0
# 8773                          8000000              -55000000.0
# 8774                         73000000             -143000000.0
# 8775                        143000000              -85000000.0
# 13729                        -1630849                -184393.0
# 13730                         -572118                -454869.0
# 13731                         -289809                 -50311.0
# 13732                         -189069                 -17132.0
# 13785                         -793669                -764167.0
# 13786                         -889489                -248195.0
# 13787                         -187809                -156315.0
# 13788                          -41798                -253431.0
# 13789                          -13499                -101313.0
# 13790                          -69942                -104257.0
# 13791                          -17306                 -19482.0
# 14554                        -7288487                -107249.0
# 14809                         -687815                -171195.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 1221             -506000000                         35000000.0
# 1222            -1752000000                        284000000.0
# 8144              344600000                        -47500000.0
# 8145              397600000                        -40000000.0
# 8146              193300000                        -43900000.0
# 8147              273500000                        -59000000.0
# 8148              -27900000                        -27400000.0
# 8149              108957000                        -60385000.0
# 8150               17124000                        -92295000.0
# 8151             -124183000                        -63189000.0
# 8770             -331000000                         60000000.0
# 8771               53000000                       -236000000.0
# 8772              -49000000                       -120000000.0
# 8773              -47000000                       -257000000.0
# 8774              -70000000                       -299000000.0
# 8775               58000000                       -295000000.0
# 13729              -1815242                                NaN
# 13730              -1026987                                NaN
# 13731               -340120                                NaN
# 13732               -206201                                0.0
# 13785              -1557836                                0.0
# 13786              -1137684                                0.0
# 13787               -344124                                0.0
# 13788               -295229                                NaN
# 13789               -114812                                0.0
# 13790               -174199                                0.0
# 13791                -36788                                0.0
# 14554              -7395736                            14665.0
# 14809               -859010                                0.0
#
#        Income (Loss) From Continuing Operations  \
# 1221                                 -471000000
# 1222                                -1468000000
# 8144                                  297100000
# 8145                                  357600000
# 8146                                  149400000
# 8147                                  214500000
# 8148                                  -55300000
# 8149                                   48572000
# 8150                                  -75171000
# 8151                                 -187372000
# 8770                                 -271000000
# 8771                                 -183000000
# 8772                                 -169000000
# 8773                                 -304000000
# 8774                                 -369000000
# 8775                                 -237000000
# 13729                                  -1815242
# 13730                                  -1026987
# 13731                                   -340120
# 13732                                   -206201
# 13785                                  -1557836
# 13786                                  -1137684
# 13787                                   -344124
# 13788                                   -295229
# 13789                                   -114812
# 13790                                   -174199
# 13791                                    -36788
# 14554                                  -7381071
# 14809                                   -859010
#
#        Net Extraordinary Gains (Losses)  Net Income  \
# 1221                                NaN  -471000000
# 1222                                NaN -1468000000
# 8144                                NaN   295800000
# 8145                                NaN   357100000
# 8146                                NaN   148900000
# 8147                                NaN   214100000
# 8148                                NaN   -55200000
# 8149                                NaN    48572000
# 8150                                NaN   -75171000
# 8151                         -2735000.0  -190107000
# 8770                                NaN  -271000000
# 8771                                NaN  -183000000
# 8772                                NaN  -169000000
# 8773                                NaN  -304000000
# 8774                                NaN  -369000000
# 8775                                NaN  -237000000
# 13729                               NaN    -1815242
# 13730                               NaN    -1026987
# 13731                               NaN     -340120
# 13732                               NaN     -206201
# 13785                               NaN    -1557836
# 13786                               NaN    -1137684
# 13787                               NaN     -344124
# 13788                               NaN     -295229
# 13789                               NaN     -114812
# 13790                               NaN     -174199
# 13791                               NaN      -36788
# 14554                               NaN    -7381071
# 14809                               NaN     -859010
#
#        Net Income Available to Common Shareholders
# 1221                                    -471000000
# 1222                                   -1468000000
# 8144                                     295800000
# 8145                                     357100000
# 8146                                     148900000
# 8147                                     214100000
# 8148                                     -55200000
# 8149                                      48572000
# 8150                                     -75171000
# 8151                                    -190107000
# 8770                                    -271000000
# 8771                                    -183000000
# 8772                                    -169000000
# 8773                                    -304000000
# 8774                                    -369000000
# 8775                                    -237000000
# 13729                                     -1815242
# 13730                                     -1026987
# 13731                                      -340120
# 13732                                      -206201
# 13785                                     -1557836
# 13786                                     -1137684
# 13787                                      -344124
# 13788                                      -295229
# 13789                                      -114812
# 13790                                      -174199
# 13791                                       -36788
# 14554                                     -7381071
# 14809                                      -859010
#
# [29 rows x 27 columns]

# %% [markdown]
# ## Shares Diluted is None or <= 0

# %%
test_name = "SHARES_DILUTED is None or <= 0"
test_func_rows = lambda df: (df[SHARES_DILUTED] is None or
                             df[SHARES_DILUTED] <= 0)
test_datasets(datasets=datasets_fundamental,
              test_name=test_name, test_func_rows=test_func_rows)
# Out:
# SHARES_DILUTED is None or <= 0
# dataset='income', variant='annual', market='us'
# dataset='income', variant='annual-full', market='us'
# dataset='income', variant='quarterly', market='us'
# dataset='income', variant='quarterly-full', market='us'
# dataset='income', variant='ttm', market='us'
# dataset='income', variant='ttm-full', market='us'
# dataset='income-banks', variant='quarterly', market='us'
# dataset='income-banks', variant='quarterly-full', market='us'
# dataset='income-banks', variant='ttm', market='us'
# dataset='income-banks', variant='ttm-full', market='us'
# dataset='income-insurance', variant='quarterly', market='us'
# dataset='income-insurance', variant='quarterly-full', market='us'
# dataset='income-insurance', variant='ttm', market='us'
# dataset='income-insurance', variant='ttm-full', market='us'
# dataset='balance', variant='annual', market='us'
# dataset='balance', variant='annual-full', market='us'
# dataset='balance', variant='quarterly', market='us'
# dataset='balance', variant='quarterly-full', market='us'
# dataset='balance', variant='ttm', market='us'
# dataset='balance', variant='ttm-full', market='us'
# dataset='balance-banks', variant='annual', market='us'
# dataset='balance-banks', variant='annual-full', market='us'
# dataset='balance-banks', variant='quarterly', market='us'
# dataset='balance-banks', variant='quarterly-full', market='us'
# dataset='balance-banks', variant='ttm', market='us'
# dataset='balance-banks', variant='ttm-full', market='us'
# dataset='balance-insurance', variant='annual', market='us'
# dataset='balance-insurance', variant='annual-full', market='us'
# dataset='balance-insurance', variant='quarterly', market='us'
# dataset='balance-insurance', variant='quarterly-full', market='us'
# dataset='balance-insurance', variant='ttm', market='us'
# dataset='balance-insurance', variant='ttm-full', market='us'
# dataset='cashflow', variant='annual', market='us'
# dataset='cashflow', variant='annual-full', market='us'
# dataset='cashflow', variant='quarterly', market='us'
# dataset='cashflow', variant='quarterly-full', market='us'
# dataset='cashflow', variant='ttm', market='us'
# dataset='cashflow', variant='ttm-full', market='us'
# dataset='cashflow-banks', variant='quarterly', market='us'
# dataset='cashflow-banks', variant='quarterly-full', market='us'
# dataset='cashflow-banks', variant='ttm', market='us'
# dataset='cashflow-banks', variant='ttm-full', market='us'
# dataset='cashflow-insurance', variant='quarterly', market='us'
# dataset='cashflow-insurance', variant='quarterly-full', market='us'
# dataset='cashflow-insurance', variant='ttm', market='us'
# dataset='cashflow-insurance', variant='ttm-full', market='us'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-18-14dce2e672c9> in <module>
#       3                              df[SHARES_DILUTED] <= 0)
#       4 test_datasets(datasets=datasets_fundamental,
# ----> 5               test_name=test_name, test_func_rows=test_func_rows)
#
# <ipython-input-7-b3d44117203b> in test_datasets(test_name, datasets, variants, markets, test_func, test_func_rows, process_df_none, raise_exception)
#      98     # Raise exception?
#      99     if num_problems>0 and raise_exception:
# --> 100         raise Exception(test_name)
#
# Exception: SHARES_DILUTED is None or <= 0

# %%
# Show the problematic rows for a dataset.
df = data.get(dataset='income', variant='quarterly', market='us')
get_problem_rows(df=df, test_func_rows=test_func_rows)
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 612      ENS     35886      USD         2010            Q4  2011-03-31
# 613      ENS     35886      USD         2011            Q4  2012-03-31
# 819      JOY     39382      USD         2009            Q4  2009-10-31
# 1008    AXON     41996      USD         2018            Q4  2019-03-31
# 1383       A     45846      USD         2013            Q4  2013-10-31
# ...      ...       ...      ...          ...           ...         ...
# 64597   JAKK    908372      USD         2016            Q4  2016-12-31
# 64779   KYAK    910478      USD         2011            Q1  2011-03-31
# 64890   BWXT    914354      USD         2013            Q4  2013-12-31
# 64898   BWXT    914354      USD         2011            Q4  2011-12-31
# 65454   HCSG    923327      USD         2010            Q4  2010-12-31
#
#       Publish Date  Shares (Basic)  Shares (Diluted)       Revenue  ...  \
# 612     2011-02-09   -1.248976e+09     -1.266011e+09  4.505370e+08  ...
# 613     2011-05-31   -3.893758e+08     -3.943303e+08  5.480540e+08  ...
# 819     2010-06-08   -3.068902e+08     -3.085706e+08  9.635280e+08  ...
# 1008    2019-06-11   -2.930225e+08     -2.930225e+08           NaN  ...
# 1383    2013-12-19   -7.940000e+07     -8.160000e+07 -1.170000e+09  ...
# ...            ...             ...               ...           ...  ...
# 64597   2017-03-16    1.650400e+07     -6.464000e+06  1.670260e+08  ...
# 64779   2012-09-20    7.397969e+06     -2.248806e+07  5.267400e+07  ...
# 64890   2014-02-26   -2.409151e+07     -2.406707e+07 -9.197300e+08  ...
# 64898   2012-05-09   -1.645524e+11     -1.656942e+11  8.007890e+08  ...
# 65454   2011-04-25   -1.615000e+05     -4.250000e+04  2.020870e+08  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 612                     -6217000.0             -5991000.0
# 613                     -5907000.0             -4361000.0
# 819                     -5322000.0             -5322000.0
# 1008                    -1447000.0             -1722000.0
# 1383                   -32000000.0            -28000000.0
# ...                            ...                    ...
# 64597                   -3453000.0             -3504000.0
# 64779                     632000.0                21000.0
# 64890                  -24216000.0             -1335000.0
# 64898                   18330000.0             -1690000.0
# 65454                    1073000.0              1073000.0
#
#        Pretax Income (Loss), Adjusted  Abnormal Gains (Losses)  \
# 612                          30983000               -6163000.0
# 613                          49197000               -9741000.0
# 819                         178780000                5585000.0
# 1008                        -14753000                      NaN
# 1383                       -312000000                      NaN
# ...                               ...                      ...
# 64597                        -5844000                      NaN
# 64779                         3587000              -14980000.0
# 64890                        37972000                5725000.0
# 64898                       -54552000                3713000.0
# 65454                        14437000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 612                24820000                         -6991000.0
# 613                39456000                         -9365000.0
# 819               184365000                        -60340000.0
# 1008               -9137000                            91000.0
# 1383             -312000000                         24000000.0
# ...                     ...                                ...
# 64597              -5844000                         -1908000.0
# 64779             -11393000                          4479000.0
# 64890              43697000                        -30582000.0
# 64898             -50839000                         21544000.0
# 65454              14437000                         -5314000.0
#
#        Income (Loss) From Continuing Operations  \
# 612                                    17829000
# 613                                    30091000
# 819                                   124025000
# 1008                                   -9046000
# 1383                                 -288000000
# ...                                         ...
# 64597                                  -7752000
# 64779                                  -6914000
# 64890                                  13115000
# 64898                                 -29295000
# 65454                                   9123000
#
#        Net Extraordinary Gains (Losses)  Net Income  \
# 612                                 NaN    17829000
# 613                                 NaN    30091000
# 819                                 NaN   124025000
# 1008                                NaN    -9046000
# 1383                                NaN   221000000
# ...                                 ...         ...
# 64597                               NaN    -7585000
# 64779                               NaN    -6914000
# 64890                               NaN   165588000
# 64898                               NaN   -27063000
# 65454                               NaN     9123000
#
#        Net Income Available to Common Shareholders
# 612                                       17829000
# 613                                       30091000
# 819                                      124025000
# 1008                                      -9046000
# 1383                                     221000000
# ...                                            ...
# 64597                                     -7585000
# 64779                                     -9850000
# 64890                                    165588000
# 64898                                    -27063000
# 65454                                      9123000
#
# [401 rows x 27 columns]

# %% [markdown]
# ## Revenue is negative

# %%
test_name = "REVENUE < 0"
test_func_rows = lambda df: (df[REVENUE] < 0)
test_datasets(datasets=datasets_income,
              test_name=test_name, test_func_rows=test_func_rows)
# Out:
# REVENUE < 0
# dataset='income', variant='annual', market='us'
# dataset='income', variant='annual-full', market='us'
# dataset='income', variant='quarterly', market='us'
# dataset='income', variant='quarterly-full', market='us'
# dataset='income', variant='ttm', market='us'
# dataset='income', variant='ttm-full', market='us'
# dataset='income-banks', variant='annual', market='ca'
# dataset='income-banks', variant='annual', market='de'
# dataset='income-banks', variant='annual', market='it'
# dataset='income-banks', variant='annual', market='sg'
# dataset='income-banks', variant='annual', market='us'
# dataset='income-banks', variant='annual-full', market='ca'
# dataset='income-banks', variant='annual-full', market='de'
# dataset='income-banks', variant='annual-full', market='it'
# dataset='income-banks', variant='annual-full', market='sg'
# dataset='income-banks', variant='annual-full', market='us'
# dataset='income-banks', variant='quarterly', market='ca'
# dataset='income-banks', variant='quarterly', market='de'
# dataset='income-banks', variant='quarterly', market='it'
# dataset='income-banks', variant='quarterly', market='sg'
# dataset='income-banks', variant='quarterly', market='us'
# dataset='income-banks', variant='quarterly-full', market='ca'
# dataset='income-banks', variant='quarterly-full', market='de'
# dataset='income-banks', variant='quarterly-full', market='it'
# dataset='income-banks', variant='quarterly-full', market='sg'
# dataset='income-banks', variant='quarterly-full', market='us'
# dataset='income-banks', variant='ttm', market='ca'
# dataset='income-banks', variant='ttm', market='de'
# dataset='income-banks', variant='ttm', market='it'
# dataset='income-banks', variant='ttm', market='sg'
# dataset='income-banks', variant='ttm', market='us'
# dataset='income-banks', variant='ttm-full', market='ca'
# dataset='income-banks', variant='ttm-full', market='de'
# dataset='income-banks', variant='ttm-full', market='it'
# dataset='income-banks', variant='ttm-full', market='sg'
# dataset='income-banks', variant='ttm-full', market='us'
# dataset='income-insurance', variant='annual', market='ca'
# dataset='income-insurance', variant='annual', market='de'
# dataset='income-insurance', variant='annual', market='it'
# dataset='income-insurance', variant='annual', market='sg'
# dataset='income-insurance', variant='annual', market='us'
# dataset='income-insurance', variant='annual-full', market='ca'
# dataset='income-insurance', variant='annual-full', market='de'
# dataset='income-insurance', variant='annual-full', market='it'
# dataset='income-insurance', variant='annual-full', market='sg'
# dataset='income-insurance', variant='annual-full', market='us'
# dataset='income-insurance', variant='quarterly', market='ca'
# dataset='income-insurance', variant='quarterly', market='de'
# dataset='income-insurance', variant='quarterly', market='it'
# dataset='income-insurance', variant='quarterly', market='sg'
# dataset='income-insurance', variant='quarterly', market='us'
# dataset='income-insurance', variant='quarterly-full', market='ca'
# dataset='income-insurance', variant='quarterly-full', market='de'
# dataset='income-insurance', variant='quarterly-full', market='it'
# dataset='income-insurance', variant='quarterly-full', market='sg'
# dataset='income-insurance', variant='quarterly-full', market='us'
# dataset='income-insurance', variant='ttm', market='ca'
# dataset='income-insurance', variant='ttm', market='de'
# dataset='income-insurance', variant='ttm', market='it'
# dataset='income-insurance', variant='ttm', market='sg'
# dataset='income-insurance', variant='ttm', market='us'
# dataset='income-insurance', variant='ttm-full', market='ca'
# dataset='income-insurance', variant='ttm-full', market='de'
# dataset='income-insurance', variant='ttm-full', market='it'
# dataset='income-insurance', variant='ttm-full', market='sg'
# dataset='income-insurance', variant='ttm-full', market='us'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-20-2cc1592b6b33> in <module>
#       2 test_func_rows = lambda df: (df[REVENUE] < 0)
#       3 test_datasets(datasets=datasets_income,
# ----> 4               test_name=test_name, test_func_rows=test_func_rows)
#
# <ipython-input-7-b3d44117203b> in test_datasets(test_name, datasets, variants, markets, test_func, test_func_rows, process_df_none, raise_exception)
#      98     # Raise exception?
#      99     if num_problems>0 and raise_exception:
# --> 100         raise Exception(test_name)
#
# Exception: REVENUE < 0

# %%
# Show the problematic rows for a dataset.
df = data.get(dataset='income', variant='quarterly', market='us')
get_problem_rows(df=df, test_func_rows=test_func_rows)
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 59       FOX       242      USD         2011            Q4  2011-06-30
# 60       FOX       242      USD         2012            Q4  2012-06-30
# 276      PPL     26853      USD         2013            Q4  2013-12-31
# 1383       A     45846      USD         2013            Q4  2013-10-31
# 1510     HPE     47023      USD         2015            Q4  2015-10-31
# ...      ...       ...      ...          ...           ...         ...
# 65960    MSB    942591      USD         2018            Q4  2019-01-31
# 65962    MSB    942591      USD         2010            Q4  2011-01-31
# 65974   INVA    942592      USD         2014            Q1  2014-03-31
# 65993   INVA    942592      USD         2012            Q4  2012-12-31
# 66061   BSHF    943379      USD         2011            Q4  2011-04-30
#
#       Publish Date  Shares (Basic)  Shares (Diluted)       Revenue  ...  \
# 59      2011-08-15    2.626000e+09      2.647000e+09 -2.110000e+08  ...
# 60      2012-08-14    2.413000e+09      2.414000e+09 -2.850000e+08  ...
# 276     2014-02-24    5.061656e+08      5.272955e+08 -1.718000e+09  ...
# 1383    2013-12-19   -7.940000e+07     -8.160000e+07 -1.170000e+09  ...
# 1510    2016-09-08   -2.069368e+09      3.146594e+09 -7.582000e+09  ...
# ...            ...             ...               ...           ...  ...
# 65960   2019-04-12    1.312001e+07               NaN -3.954987e+07  ...
# 65962   2012-04-13             NaN               NaN -2.778889e+07  ...
# 65974   2014-05-07    1.098590e+08      1.098590e+08 -7.800000e+05  ...
# 65993   2013-02-26    3.158136e+07      2.105376e+07 -1.243460e+08  ...
# 66061   2012-08-14    1.017135e+08      1.017135e+08 -1.541880e+05  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 59                    -175000000.0           -266000000.0
# 60                    -101000000.0           -273000000.0
# 276                    -98000000.0            -25000000.0
# 1383                   -32000000.0            -28000000.0
# 1510                    33000000.0             35000000.0
# ...                            ...                    ...
# 65960                          NaN                    NaN
# 65962                          NaN                    NaN
# 65974                   -1459000.0             -1644000.0
# 65993                   -1344000.0             -1500000.0
# 66061                      -7587.0                -7587.0
#
#        Pretax Income (Loss), Adjusted  Abnormal Gains (Losses)  \
# 59                          278000000               -3000000.0
# 60                          663000000              -47000000.0
# 276                         166000000                      NaN
# 1383                       -312000000                      NaN
# 1510                        401000000              174000000.0
# ...                               ...                      ...
# 65960                         6786679                      NaN
# 65962                         5272369                      NaN
# 65974                       -16182000                      NaN
# 65993                       -43471000                      NaN
# 66061                         -516421               -3020749.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 59                275000000                        -16000000.0
# 60                616000000                       -163000000.0
# 276               166000000                        -19000000.0
# 1383             -312000000                         24000000.0
# 1510              575000000                        989000000.0
# ...                     ...                                ...
# 65960               6786679                                NaN
# 65962               5272369                                NaN
# 65974             -16182000                                NaN
# 65993             -43471000                                NaN
# 66061              -3537170                                0.0
#
#        Income (Loss) From Continuing Operations  \
# 59                                    259000000
# 60                                    453000000
# 276                                   147000000
# 1383                                 -288000000
# 1510                                 1564000000
# ...                                         ...
# 65960                                   6786679
# 65962                                   5272369
# 65974                                 -16182000
# 65993                                 -43471000
# 66061                                  -3537170
#
#        Net Extraordinary Gains (Losses)  Net Income  \
# 59                                  NaN   683000000
# 60                                  NaN -1553000000
# 276                                 NaN   -98000000
# 1383                                NaN   221000000
# 1510                                NaN  1385000000
# ...                                 ...         ...
# 65960                               NaN     6786679
# 65962                               NaN     5272369
# 65974                       -51521000.0   -67703000
# 65993                               NaN   -31324000
# 66061                               NaN    -3537170
#
#        Net Income Available to Common Shareholders
# 59                                       683000000
# 60                                     -1553000000
# 276                                      -98000000
# 1383                                     221000000
# 1510                                    1385000000
# ...                                            ...
# 65960                                      6786679
# 65962                                      5272369
# 65974                                    -67703000
# 65993                                    -31324000
# 66061                                     -3537170
#
# [244 rows x 27 columns]

# %% [markdown]
# ## Assets != Liabilities + Equity (Exact Comparison)

# %%
test_name = "Assets != Liabilities + Equity (Exact Comparison)"
test_func_rows = lambda df: (df[TOTAL_ASSETS] != df[TOTAL_LIABILITIES] + df[TOTAL_EQUITY])
test_datasets(datasets=datasets_balance,
              test_name=test_name, test_func_rows=test_func_rows)
# Out:
# Assets != Liabilities + Equity (Exact Comparison)
# dataset='balance', variant='annual', market='de'
# dataset='balance', variant='annual', market='us'
# dataset='balance', variant='annual-full', market='de'
# dataset='balance', variant='annual-full', market='us'
# dataset='balance', variant='quarterly', market='de'
# dataset='balance', variant='quarterly', market='us'
# dataset='balance', variant='quarterly-full', market='de'
# dataset='balance', variant='quarterly-full', market='us'
# dataset='balance', variant='ttm', market='de'
# dataset='balance', variant='ttm', market='us'
# dataset='balance', variant='ttm-full', market='de'
# dataset='balance', variant='ttm-full', market='us'
# dataset='balance-banks', variant='annual', market='us'
# dataset='balance-banks', variant='annual-full', market='us'
# dataset='balance-banks', variant='quarterly', market='de'
# dataset='balance-banks', variant='quarterly', market='us'
# dataset='balance-banks', variant='quarterly-full', market='de'
# dataset='balance-banks', variant='quarterly-full', market='us'
# dataset='balance-banks', variant='ttm', market='de'
# dataset='balance-banks', variant='ttm', market='us'
# dataset='balance-banks', variant='ttm-full', market='de'
# dataset='balance-banks', variant='ttm-full', market='us'
# dataset='balance-insurance', variant='annual', market='us'
# dataset='balance-insurance', variant='annual-full', market='us'
# dataset='balance-insurance', variant='quarterly', market='us'
# dataset='balance-insurance', variant='quarterly-full', market='us'
# dataset='balance-insurance', variant='ttm', market='us'
# dataset='balance-insurance', variant='ttm-full', market='us'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-22-33d4b331236b> in <module>
#       2 test_func_rows = lambda df: (df[TOTAL_ASSETS] != df[TOTAL_LIABILITIES] + df[TOTAL_EQUITY])
#       3 test_datasets(datasets=datasets_balance,
# ----> 4               test_name=test_name, test_func_rows=test_func_rows)
#
# <ipython-input-7-b3d44117203b> in test_datasets(test_name, datasets, variants, markets, test_func, test_func_rows, process_df_none, raise_exception)
#      98     # Raise exception?
#      99     if num_problems>0 and raise_exception:
# --> 100         raise Exception(test_name)
#
# Exception: Assets != Liabilities + Equity (Exact Comparison)

# %%
# Get the problematic rows for a dataset.
df = data.get(dataset='balance', variant='quarterly', market='us')
df2 = get_problem_rows(df=df, test_func_rows=test_func_rows)

# Only show the relevant columns.
df2[[TICKER, SIMFIN_ID, REPORT_DATE, TOTAL_ASSETS, TOTAL_LIABILITIES, TOTAL_EQUITY]]
# Out:
#       Ticker  SimFinId Report Date  Total Assets  Total Liabilities  \
# 121      BLK       914  2011-02-28  178459000000       1.521250e+11
# 124      BLK       914  2010-02-28  178124000000       1.535220e+11
# 398     ACAT     33956  2011-09-30     357162000       1.522490e+08
# 494      ENS     35886  2016-09-30    2264838000       1.185643e+09
# 495      ENS     35886  2016-06-30    2204571000       1.168335e+09
# ...      ...       ...         ...           ...                ...
# 61270   BLGO    943380  2013-12-31        126196       7.321570e+05
# 61271   BLGO    943380  2013-09-30         94249       5.013070e+05
# 61272   BLGO    943380  2013-06-30        127168       7.481080e+05
# 61273   BLGO    943380  2013-03-31        151457       6.816830e+05
# 61274   BLGO    943380  2012-12-31        216780       5.583690e+05
#
#        Total Equity
# 121    2.633300e+10
# 124    2.460100e+10
# 398    2.049120e+08
# 494    1.076018e+09
# 495    1.030288e+09
# ...             ...
# 61270 -5.649640e+05
# 61271 -3.633310e+05
# 61272 -5.744830e+05
# 61273 -4.810390e+05
# 61274 -2.896720e+05
#
# [1584 rows x 6 columns]

# %% [markdown]
# ## Assets != Liabilities + Equity (1% Tolerance)
#
# The above test used exact comparison. We now allow for 1% error.

# %%
def test_func_rows(df):
    x = df[TOTAL_ASSETS]
    y = df[TOTAL_LIABILITIES] + df[TOTAL_EQUITY]
    
    # Compare x and y within 1% tolerance. Note the resulting
    # boolean array is negated because we want to indicate
    # which rows are problematic so x and y are not close.
    return ~isclose(x=x, y=y, tolerance=0.01)

# %%
test_name = "Assets != Liabilities + Equity (1% Tolerance)"
test_datasets(datasets=datasets_balance,
              test_name=test_name, test_func_rows=test_func_rows)
# Out:
# Assets != Liabilities + Equity (1% Tolerance)
# dataset='balance', variant='annual', market='de'
# dataset='balance', variant='annual', market='us'
# dataset='balance', variant='annual-full', market='de'
# dataset='balance', variant='annual-full', market='us'
# dataset='balance', variant='quarterly', market='de'
# dataset='balance', variant='quarterly', market='us'
# dataset='balance', variant='quarterly-full', market='de'
# dataset='balance', variant='quarterly-full', market='us'
# dataset='balance', variant='ttm', market='de'
# dataset='balance', variant='ttm', market='us'
# dataset='balance', variant='ttm-full', market='de'
# dataset='balance', variant='ttm-full', market='us'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-25-93e621776966> in <module>
#       1 test_name = "Assets != Liabilities + Equity (1% Tolerance)"
#       2 test_datasets(datasets=datasets_balance,
# ----> 3               test_name=test_name, test_func_rows=test_func_rows)
#
# <ipython-input-7-b3d44117203b> in test_datasets(test_name, datasets, variants, markets, test_func, test_func_rows, process_df_none, raise_exception)
#      98     # Raise exception?
#      99     if num_problems>0 and raise_exception:
# --> 100         raise Exception(test_name)
#
# Exception: Assets != Liabilities + Equity (1% Tolerance)

# %%
# Get the problematic rows for a dataset.
df = data.get(dataset='balance', variant='quarterly', market='us')
df2 = get_problem_rows(df=df, test_func_rows=test_func_rows)

# Only show the relevant columns.
df2[[TICKER, SIMFIN_ID, REPORT_DATE, TOTAL_ASSETS, TOTAL_LIABILITIES, TOTAL_EQUITY]]
# Out:
#       Ticker  SimFinId Report Date  Total Assets  Total Liabilities  \
# 3034     AES     62329  2018-06-30   32597000000       2.607700e+10
# 3035     AES     62329  2018-03-31   32573000000       2.619700e+10
# 3036     AES     62329  2017-12-31   33112000000       2.743000e+10
# 3037     AES     62329  2017-09-30   38834000000       3.168800e+10
# 3038     AES     62329  2017-06-30   36469000000       2.960400e+10
# ...      ...       ...         ...           ...                ...
# 61270   BLGO    943380  2013-12-31        126196       7.321570e+05
# 61271   BLGO    943380  2013-09-30         94249       5.013070e+05
# 61272   BLGO    943380  2013-06-30        127168       7.481080e+05
# 61273   BLGO    943380  2013-03-31        151457       6.816830e+05
# 61274   BLGO    943380  2012-12-31        216780       5.583690e+05
#
#        Total Equity
# 3034   5.657000e+09
# 3035   5.525000e+09
# 3036   4.845000e+09
# 3037   6.179000e+09
# 3038   6.074000e+09
# ...             ...
# 61270 -5.649640e+05
# 61271 -3.633310e+05
# 61272 -5.744830e+05
# 61273 -4.810390e+05
# 61274 -2.896720e+05
#
# [781 rows x 6 columns]

# %% [markdown]
# ## Dates are invalid (Fundamentals)

# %%
# Lambda function for converting strings to dates. Format: YYYY-MM-DD
# This will raise an exception if invalid dates are encountered.
date_parser = lambda column: pd.to_datetime(column, yearfirst=True, dayfirst=False)

# %%
# Test function for the entire DataFrame.
# This cannot show which individual rows have problems.
def test_func(df):
    result1 = date_parser(df[REPORT_DATE])
    result2 = date_parser(df[PUBLISH_DATE])
    
    # We only get to this point if date_parser() does not
    # raise any exceptions, in which case we assume the
    # data did not have any problems.
    return False

# %%
test_name = "REPORT_DATE or PUBLISH_DATE is invalid"
test_datasets(datasets=datasets_fundamental,
              test_name=test_name, test_func=test_func)

# %% [markdown]
# ## Dates are invalid (Share-Prices)

# %%
# Test function for the entire DataFrame.
# This cannot show which individual rows have problems.
def test_func(df):
    result1 = date_parser(df[DATE])
    
    # We only get to this point if date_parser() does not
    # raise any exceptions, in which case we assume the
    # data did not have any problems.
    return False

# %%
test_name = "DATE is invalid"
test_datasets(datasets=datasets_shareprices,
              test_name=test_name, test_func=test_func)

# %% [markdown]
# ## Duplicate Tickers

# %%
def get_duplicate_tickers(df):
    """
    Return the rows of `df` where multiple SIMFIN_ID
    have the same TICKER.
    
    :param df: Pandas DataFrame with TICKER column.
    :return: Pandas DataFrame.
    """

    # Remove duplicate rows of [TICKER, SIMFIN_ID] pairs.
    # For the 'companies' dataset this is not necessary,
    # but for e.g. the 'income' dataset we have many rows
    # for each [TICKER, SIMFIN_ID] pair because there are
    # many financial reports for each of these ID pairs.
    idx = df[[TICKER, SIMFIN_ID]].duplicated()
    df2 = df[~idx]

    # Now the DataFrame df2 only contains unique rows of
    # [TICKER, SIMFIN_ID] so we need to check if there are
    # any duplicate TICKER.

    # Index for rows where TICKER is a duplicate.
    idx1 = df2[TICKER].duplicated()

    # Index for rows where TICKER is not NaN.
    # These would otherwise show up as duplicates.
    idx2 = df2[TICKER].notna()

    # Index for rows where TICKER is a duplicate but not NaN.
    idx = idx1 & idx2

    # Get those rows from the DataFrame.
    df2 = df2[idx]

    return df2

# %%
# Test-function whether a DataFrame has duplicate tickers.
test_func = lambda df: (len(get_duplicate_tickers(df=df)) > 0)

# %%
# Test whether these datasets have duplicate tickers.
# It might only be necessary for 'companies' but we
# might as well test all datasets that use tickers.
_datasets = ['companies'] + datasets_fundamental + datasets_shareprices

# %%
test_name = "Duplicate Tickers"
test_datasets(datasets=_datasets,
              test_name=test_name, test_func=test_func)
# Out:
# Duplicate Tickers
# dataset='companies', variant='None', market='us'
# dataset='income', variant='annual', market='us'
# dataset='income', variant='annual-full', market='us'
# dataset='income', variant='quarterly', market='us'
# dataset='income', variant='quarterly-full', market='us'
# dataset='income', variant='ttm', market='us'
# dataset='income', variant='ttm-full', market='us'
# dataset='balance', variant='annual', market='us'
# dataset='balance', variant='annual-full', market='us'
# dataset='balance', variant='quarterly', market='us'
# dataset='balance', variant='quarterly-full', market='us'
# dataset='balance', variant='ttm', market='us'
# dataset='balance', variant='ttm-full', market='us'
# dataset='cashflow', variant='annual', market='us'
# dataset='cashflow', variant='annual-full', market='us'
# dataset='cashflow', variant='quarterly', market='us'
# dataset='cashflow', variant='quarterly-full', market='us'
# dataset='cashflow', variant='ttm', market='us'
# dataset='cashflow', variant='ttm-full', market='us'
# dataset='shareprices', variant='latest', market='us'
# dataset='shareprices', variant='daily', market='us'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-35-6025322305a0> in <module>
#       1 test_name = "Duplicate Tickers"
#       2 test_datasets(datasets=_datasets,
# ----> 3               test_name=test_name, test_func=test_func)
#
# <ipython-input-7-b3d44117203b> in test_datasets(test_name, datasets, variants, markets, test_func, test_func_rows, process_df_none, raise_exception)
#      98     # Raise exception?
#      99     if num_problems>0 and raise_exception:
# --> 100         raise Exception(test_name)
#
# Exception: Duplicate Tickers

# %%
# Show duplicate tickers in the 'companies' dataset.
df = data.get(dataset='companies', market='us')
get_duplicate_tickers(df=df)
# Out:
#      Ticker  SimFinId                    Company Name  IndustryId
# 109    GOOG     61595                     Google Inc.    101002.0
# 1097    MDT    378189                   Medtronic INC    106004.0
# 1099    MYL    378191                      Mylan N.V.    106005.0
# 1202    AGN    442340                   Allergan Inc.    106005.0
# 1206    GGP    442374  General Growth Properties, Inc    109001.0
# 1247     ES    446632             Energysolutions Inc    105001.0
# 1268     FE    447804          Metropolitan Edison Co    105001.0
# 1287    SHO    448662    Sunstone Hotel Investors Inc    109001.0
# 1298    WFT    449193   Weatherford International LTD    107004.0
# 1399   ENDP    530918          Endo International plc    106005.0
# 1532    FTI    637893                  TechnipFMC plc    107004.0
# 1549   ISBC    641029         Investors Bancorp, Inc.    104002.0
# 1790   AVGO    686523                   Broadcom Inc.    101004.0
# 1791   ALTR    686620         Altair Engineering Inc.    101003.0
# 1812   ARMK    692435          Aramark Services, Inc.    103003.0
# 1814    EXC    692600  DELMARVA POWER & LIGHT CO /DE/    105001.0
# 1887    DUK    709706      DUKE ENERGY PROGRESS, LLC.    105001.0
# 2401   FANG    896740        Diamondback Energy, Inc.    107002.0
# 2424    LSI    901127              LIFE STORAGE, INC.    109001.0
# 2433   LDOS    902720           Leidos Holdings, Inc.    101003.0

# %%
# Show duplicate tickers in the 'income-annual' dataset.
df = data.get(dataset='income', variant='annual', market='us')
get_duplicate_tickers(df=df)
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 886     GOOG     61595      USD         2015            FY  2015-12-31
# 9465     MDT    378189      USD         2013            FY  2013-04-30
# 9484     MYL    378191      USD         2014            FY  2014-12-31
# 10416    AGN    442340      USD         2014            FY  2014-12-31
# 10805     ES    446632      USD         2013            FY  2013-12-31
# 10950     FE    447804      USD         2011            FY  2011-12-31
# 11108    SHO    448662      USD         2015            FY  2015-12-31
# 11192    WFT    449193      USD         2013            FY  2013-12-31
# 11987   ENDP    530918      USD         2017            FY  2017-12-31
# 12988    FTI    637893      USD         2017            FY  2017-12-31
# 14293   AVGO    686523      USD         2018            FY  2018-11-30
# 14296   ALTR    686620      USD         2017            FY  2017-12-31
# 14415   ARMK    692435      USD         2012            FY  2012-09-30
# 14426    EXC    692600      USD         2017            FY  2017-12-31
# 14869    DUK    709706      USD         2018            FY  2018-12-31
# 17143    LSI    901127      USD         2018            FY  2018-12-31
# 17195   LDOS    902720      USD         2018            FY  2019-01-31
#
#       Publish Date  Shares (Basic)  Shares (Diluted)       Revenue  ...  \
# 886     2016-02-11    6.846260e+08      7.446750e+08  7.498900e+10  ...
# 9465    2014-06-20    1.002100e+09      1.013600e+09  1.700500e+10  ...
# 9484    2015-03-02    3.737000e+08      3.980000e+08  7.719600e+09  ...
# 10416   2015-02-19    2.976000e+08      3.040000e+08  7.237900e+09  ...
# 10805   2014-03-31             NaN               NaN  1.804398e+09  ...
# 10950   2012-02-28    3.990000e+08      4.010000e+08  1.625800e+10  ...
# 11108   2016-02-23    2.073500e+08      2.073500e+08  1.249180e+09  ...
# 11192   2014-02-25    7.720000e+08      7.720000e+08  1.526300e+10  ...
# 11987   2018-02-27    2.231980e+08      2.231980e+08  3.468858e+09  ...
# 12988   2018-04-02    4.667000e+08      4.683000e+08  1.505690e+10  ...
# 14293   2018-12-21    4.180000e+08      4.310000e+08  2.084800e+10  ...
# 14296   2018-03-21    5.246600e+07      5.246600e+07  3.333330e+08  ...
# 14415   2012-12-20             NaN               NaN  1.350543e+10  ...
# 14426   2018-02-09    9.470000e+08      9.490000e+08  3.353300e+10  ...
# 14869   2019-02-28    7.080000e+08      7.080000e+08  2.452100e+10  ...
# 17143   2019-02-26    4.650100e+07      4.659700e+07  5.508500e+08  ...
# 17195   2019-02-19    1.510000e+08      1.530000e+08  1.019400e+10  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 886                   2.910000e+08                    NaN
# 9465                 -2.890000e+08          -1.080000e+08
# 9484                 -3.781000e+08          -3.332000e+08
# 10416                -2.000000e+07          -6.170000e+07
# 10805                -7.387500e+07          -7.677400e+07
# 10950                -8.940000e+08          -1.008000e+09
# 11108                -6.263100e+07          -6.651600e+07
# 11192                -5.930000e+08          -5.160000e+08
# 11987                -4.712050e+08          -4.882280e+08
# 12988                -2.855000e+08          -3.152000e+08
# 14293                -4.840000e+08          -6.280000e+08
# 14296                -3.154000e+06          -2.160000e+06
# 14415                -4.017570e+08          -4.017570e+08
# 14426                -5.360000e+08          -1.560000e+09
# 14869                -1.612000e+09          -2.094000e+09
# 17143                -6.653700e+07          -7.065900e+07
# 17195                -1.210000e+08          -1.380000e+08
#
#        Pretax Income (Loss), Adjusted  Abnormal Gains (Losses)  \
# 886                       19651000000                      NaN
# 9465                       4710000000            -1.005000e+09
# 9484                        942400000             3.210000e+07
# 10416                      1989300000             0.000000e+00
# 10805                       -46896000             0.000000e+00
# 10950                      1724000000            -2.810000e+08
# 11108                       252868000             8.819000e+07
# 11192                        59000000            -2.290000e+08
# 11987                       -32818000            -1.450186e+09
# 12988                      1110200000            -4.305000e+08
# 14293                      5425000000            -8.800000e+08
# 14296                       -36411000                      NaN
# 14415                       180470000                      NaN
# 14426                      3280000000             4.460000e+08
# 14869                      3564000000            -4.910000e+08
# 17143                       150442000             5.711600e+07
# 17195                       654000000            -4.400000e+07
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 886             19651000000                      -3.303000e+09
# 9465             3705000000                      -6.400000e+08
# 9484              974500000                      -4.140000e+07
# 10416            1989300000                      -4.567000e+08
# 10805             -46896000                      -7.769000e+06
# 10950            1443000000                      -5.740000e+08
# 11108             341058000                      -1.434000e+06
# 11192            -170000000                      -1.440000e+08
# 11987           -1483004000                       2.502930e+08
# 12988             679700000                      -5.455000e+08
# 14293            4545000000                       8.084000e+09
# 14296             -36411000                      -6.299600e+07
# 14415             180470000                      -3.887100e+07
# 14426            3726000000                       1.250000e+08
# 14869            3073000000                      -4.480000e+08
# 17143             207558000                                NaN
# 17195             610000000                      -2.800000e+07
#
#        Income (Loss) From Continuing Operations  \
# 886                                 16348000000
# 9465                                 3065000000
# 9484                                  933100000
# 10416                                1532600000
# 10805                                 -54665000
# 10950                                 869000000
# 11108                                 339624000
# 11192                                -314000000
# 11987                               -1232711000
# 12988                                 134200000
# 14293                               12629000000
# 14296                                 -99407000
# 14415                                 141599000
# 14426                                3851000000
# 14869                                2625000000
# 17143                                 207558000
# 17195                                 582000000
#
#        Net Extraordinary Gains (Losses)   Net Income  \
# 886                                 0.0  16348000000
# 9465                                0.0   3065000000
# 9484                                NaN    929400000
# 10416                        -3800000.0   1524200000
# 10805                               NaN    -54653000
# 10950                               NaN    885000000
# 11108                        15895000.0    355519000
# 11192                               NaN   -345000000
# 11987                      -802722000.0  -2035433000
# 12988                               NaN    113300000
# 14293                       -19000000.0  12259000000
# 14296                               NaN    -99407000
# 14415                          297000.0    138248000
# 14426                               NaN   3772000000
# 14869                        19000000.0   2666000000
# 17143                               NaN    206590000
# 17195                               NaN    581000000
#
#        Net Income Available to Common Shareholders
# 886                                    15826000000
# 9465                                    3065000000
# 9484                                     929400000
# 10416                                   1524200000
# 10805                                    -54653000
# 10950                                    885000000
# 11108                                    355519000
# 11192                                   -345000000
# 11987                                  -2035433000
# 12988                                    113300000
# 14293                                  12259000000
# 14296                                    -99407000
# 14415                                    138248000
# 14426                                   3772000000
# 14869                                   2666000000
# 17143                                    206590000
# 17195                                    581000000
#
# [17 rows x 27 columns]

# %% [markdown]
# ## Missing Annual Reports

# %%
def missing_annual_reports(df):
    """
    Return a list of the SIMFIN_ID's from the given DataFrame
    that have missing annual reports.
    
    :param df:
        Pandas DataFrame with a dataset e.g. 'income-annual'.
        It must have columns SIMFIN_ID and FISCAL_YEAR.

    :return:
        List of integers with SIMFIN_ID's that have missing reports.
    """
    
    # The idea is to test for each SIMFIN_ID individually,
    # whether the DataFrame has all the expected reports for
    # consecutive Fiscal Years between the min/max years.
    
    # Helper-function for processing a DataFrame for one SIMFIN_ID.
    def _missing(df):
        # Get the Fiscal Years from the DataFrame.
        fiscal_years = df[FISCAL_YEAR]

        # How many years between min and max fiscal years.
        num_years = fiscal_years.max() - fiscal_years.min() + 1

        # We expect the Series to have the same length, otherwise
        # some reports must be missing between min and max years.
        missing = (num_years != len(fiscal_years))

        return missing
    
    # Process all companies individually and get a Pandas
    # DataFrame with a boolean for each SIMFIN_ID whether
    # it has some missing Fiscal Years.
    idx = df.groupby(SIMFIN_ID).apply(_missing)

    # List of the SIMFIN_ID's that have missing reports.
    simfin_ids = list(idx[idx].index.values)

    return simfin_ids

# %%
test_name = "Missing annual reports"
test_func = lambda df: len(missing_annual_reports(df=df)) > 0
test_datasets(datasets=datasets_fundamental,
              variants=['annual'],
              test_name=test_name, test_func=test_func)
# Out:
# Missing annual reports
# dataset='income', variant='annual', market='de'
# dataset='income', variant='annual', market='sg'
# dataset='income', variant='annual', market='us'
# dataset='income-insurance', variant='annual', market='us'
# dataset='balance', variant='annual', market='de'
# dataset='balance', variant='annual', market='us'
# dataset='balance-banks', variant='annual', market='de'
# dataset='balance-banks', variant='annual', market='us'
# dataset='balance-insurance', variant='annual', market='us'
# dataset='cashflow', variant='annual', market='us'
# dataset='cashflow-banks', variant='annual', market='de'
# dataset='cashflow-banks', variant='annual', market='us'
# dataset='cashflow-insurance', variant='annual', market='us'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-39-375372658e31> in <module>
#       3 test_datasets(datasets=datasets_fundamental,
#       4               variants=['annual'],
# ----> 5               test_name=test_name, test_func=test_func)
#
# <ipython-input-7-b3d44117203b> in test_datasets(test_name, datasets, variants, markets, test_func, test_func_rows, process_df_none, raise_exception)
#      98     # Raise exception?
#      99     if num_problems>0 and raise_exception:
# --> 100         raise Exception(test_name)
#
# Exception: Missing annual reports

# %%
# Get list of SIMFIN_ID's that have missing reports for a dataset.
df = data.get(dataset='income', variant='annual', market='us')
missing_annual_reports(df=df)
# Out:
# [37910,
#  67201,
#  89750,
#  117690,
#  123505,
#  133962,
#  181659,
#  257294,
#  336622,
#  337852,
#  350340,
#  353395,
#  378142,
#  410846,
#  419436,
#  446592,
#  449198,
#  511749,
#  515845,
#  592569,
#  609619,
#  625536,
#  628030,
#  628033,
#  630304,
#  646016,
#  651624,
#  652480,
#  652699,
#  653156,
#  654363,
#  658373,
#  658466,
#  659172,
#  660712,
#  662524,
#  662568,
#  664571,
#  679470,
#  679473,
#  687925,
#  689588,
#  689895,
#  703911,
#  705165,
#  705845,
#  708961,
#  709706,
#  727266,
#  733746,
#  767563,
#  795710,
#  798466,
#  815635,
#  818918,
#  819013,
#  819348,
#  819902,
#  821235,
#  821503,
#  823898,
#  824527,
#  824887,
#  877522,
#  889944,
#  890308,
#  899359,
#  900135,
#  901127,
#  905198,
#  910562,
#  914944,
#  919132,
#  923419]

# %%
def sort_annual_reports(df, simfin_id):
    """
    Get the data for a given SIMFIN_ID and set the index to be
    the sorted Fiscal Year so it is easier to see which are missing.
    """
    return df.set_index([SIMFIN_ID, FISCAL_YEAR]).sort_index().loc[simfin_id]

# %%
# Show all the reports for a given SIMFIN_ID sorted by
# Fiscal Year so it is easier to see which are missing.
sort_annual_reports(df=df, simfin_id=37910)
# Out:
#                  Ticker Currency Fiscal Period Report Date Publish Date  \
# Fiscal Year
# 2012         CK00015847      USD            FY  2012-12-31   2015-03-26
# 2014         CK00015847      USD            FY  2014-12-31   2015-03-26
# 2015         CK00015847      USD            FY  2015-12-31   2016-03-23
# 2016         CK00015847      USD            FY  2016-12-31   2017-03-30
#
#              Shares (Basic)  Shares (Diluted)       Revenue  Cost of Revenue  \
# Fiscal Year
# 2012                    NaN               NaN  2.365339e+09    -1.700756e+09
# 2014                    NaN               NaN  2.508315e+09    -1.801798e+09
# 2015                    NaN               NaN  2.471949e+09    -1.743660e+09
# 2016                    NaN               NaN  2.456767e+09    -1.730774e+09
#
#              Gross Profit  ...  Non-Operating Income (Loss)  \
# Fiscal Year                ...
# 2012          664583000.0  ...                  -58893000.0
# 2014          706517000.0  ...                  -83379000.0
# 2015          728289000.0  ...                  -84053000.0
# 2016          725993000.0  ...                  -80889000.0
#
#              Interest Expense, Net  Pretax Income (Loss), Adjusted  \
# Fiscal Year
# 2012                   -58893000.0                       330289000
# 2014                   -83379000.0                       323574000
# 2015                   -84053000.0                       326540000
# 2016                   -80889000.0                       324562000
#
#              Abnormal Gains (Losses)  Pretax Income (Loss)  \
# Fiscal Year
# 2012                    -351831000.0             -21542000
# 2014                    -345764000.0             -22190000
# 2015                    -386805000.0             -60265000
# 2016                    -366913000.0             -42351000
#
#              Income Tax (Expense) Benefit, Net  \
# Fiscal Year
# 2012                                -1408000.0
# 2014                                 7523000.0
# 2015                                -1978000.0
# 2016                                -2212000.0
#
#              Income (Loss) From Continuing Operations  \
# Fiscal Year
# 2012                                        -22950000
# 2014                                        -14667000
# 2015                                        -62243000
# 2016                                        -44563000
#
#              Net Extraordinary Gains (Losses)  Net Income  \
# Fiscal Year
# 2012                                      NaN   -22950000
# 2014                                      NaN   -14667000
# 2015                                      NaN   -62243000
# 2016                                      NaN   -44563000
#
#              Net Income Available to Common Shareholders
# Fiscal Year
# 2012                                           -22950000
# 2014                                           -14667000
# 2015                                           -62243000
# 2016                                           -44563000
#
# [4 rows x 25 columns]

# %% [markdown]
# ## Missing Quarterly Reports

# %%
def missing_quarterly_reports(df):
    """
    Return a list of the SIMFIN_ID's from the given DataFrame
    that have missing quarterly or ttm reports.
    
    :param df:
        Pandas DataFrame with a dataset e.g. 'income-annual'.
        It must have columns SIMFIN_ID, FISCAL_YEAR, FISCAL_PERIOD.

    :return:
        List of integers with SIMFIN_ID's that have missing reports.
    """
    
    # The idea is to test for each SIMFIN_ID individually,
    # whether the DataFrame has all the expected reports for
    # consecutive Fiscal Years and Periods between the min/max.
    
    # Helper-function for processing a DataFrame for one SIMFIN_ID.
    def _missing(df):
        # Get the Fiscal Years and Periods from the DataFrame.
        fiscal_years_periods = df[[FISCAL_YEAR, FISCAL_PERIOD]]

        # The first Fiscal Year and Period.
        min_year = fiscal_years_periods[FISCAL_YEAR].min()
        min_idx = (fiscal_years_periods[FISCAL_YEAR] == min_year)
        min_period = fiscal_years_periods[min_idx][FISCAL_PERIOD].min()

        # The last Fiscal Year and Period.
        max_year = fiscal_years_periods[FISCAL_YEAR].max()
        max_idx = (fiscal_years_periods[FISCAL_YEAR] == max_year)
        max_period = fiscal_years_periods[max_idx][FISCAL_PERIOD].max()

        # How many years between min and max fiscal years.
        num_years = max_year - min_year + 1

        # Total number of Fiscal Periods between first and
        # last Fiscal Years - if all Fiscal Periods were included.
        num_periods = num_years * 4

        # Used to map from Fiscal Period strings to ints.
        # This is safer and easier to understand than
        # e.g. def map_period(x): int(x[1])
        map_period = \
        {
            'Q1': 1,
            'Q2': 2,
            'Q3': 3,
            'Q4': 4
        }

        # Number of Fiscal Periods missing in the first year.
        adj_min_period = map_period[min_period] - 1

        # Number of Fiscal Periods missing in the last year.
        adj_max_period = 4 - map_period[max_period]

        # Adjust the number of Fiscal Periods between the min/max
        # Fiscal Years and Periods by subtracting those periods
        # missing in the first and last years.
        expected_periods = num_periods - adj_min_period - adj_max_period

        # If the expected number of Fiscal Periods between the
        # min and max dates, is different from the actual number
        # of Fiscal Periods in the DataFrame, then some are missing.
        missing = (expected_periods != len(fiscal_years_periods))

        return missing

    # Process all companies individually and get a Pandas
    # DataFrame with a boolean for each SIMFIN_ID whether
    # it has some missing Fiscal Years.
    idx = df.groupby(SIMFIN_ID).apply(_missing)

    # List of the SIMFIN_ID's that have missing reports.
    simfin_ids = list(idx[idx].index.values)

    return simfin_ids

# %%
test_name = "Missing quarterly reports"
test_func = lambda df: len(missing_quarterly_reports(df=df)) > 0
test_datasets(datasets=datasets_fundamental,
              variants=['quarterly'],
              test_name=test_name, test_func=test_func)
# Out:
# Missing quarterly reports
# dataset='income', variant='quarterly', market='de'
# dataset='income', variant='quarterly', market='sg'
# dataset='income', variant='quarterly', market='us'
# dataset='income-banks', variant='quarterly', market='us'
# dataset='income-insurance', variant='quarterly', market='us'
# dataset='balance', variant='quarterly', market='de'
# dataset='balance', variant='quarterly', market='us'
# dataset='balance-banks', variant='quarterly', market='de'
# dataset='balance-banks', variant='quarterly', market='us'
# dataset='balance-insurance', variant='quarterly', market='us'
# dataset='cashflow', variant='quarterly', market='de'
# dataset='cashflow', variant='quarterly', market='us'
# dataset='cashflow-banks', variant='quarterly', market='de'
# dataset='cashflow-banks', variant='quarterly', market='us'
# dataset='cashflow-insurance', variant='quarterly', market='us'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-44-682752376ff0> in <module>
#       3 test_datasets(datasets=datasets_fundamental,
#       4               variants=['quarterly'],
# ----> 5               test_name=test_name, test_func=test_func)
#
# <ipython-input-7-b3d44117203b> in test_datasets(test_name, datasets, variants, markets, test_func, test_func_rows, process_df_none, raise_exception)
#      98     # Raise exception?
#      99     if num_problems>0 and raise_exception:
# --> 100         raise Exception(test_name)
#
# Exception: Missing quarterly reports

# %%
# Get list of SIMFIN_ID's that have missing reports for a dataset.
df = data.get(dataset='income', variant='quarterly', market='us')
missing_quarterly_reports(df=df)
# Out:
# [36205,
#  60906,
#  67201,
#  73420,
#  82671,
#  82753,
#  82963,
#  86808,
#  89750,
#  91899,
#  98663,
#  108139,
#  117059,
#  117690,
#  122208,
#  122759,
#  123505,
#  123623,
#  124551,
#  133865,
#  133962,
#  136247,
#  138152,
#  139560,
#  144111,
#  164920,
#  181659,
#  184064,
#  185450,
#  188922,
#  189248,
#  210709,
#  217619,
#  230667,
#  231124,
#  233893,
#  242378,
#  243720,
#  256896,
#  257294,
#  258154,
#  258455,
#  259098,
#  286194,
#  286288,
#  286372,
#  329205,
#  333440,
#  334921,
#  336622,
#  337852,
#  340222,
#  340525,
#  350160,
#  350340,
#  352171,
#  353395,
#  353811,
#  354347,
#  358146,
#  359467,
#  360213,
#  362372,
#  368990,
#  370817,
#  378117,
#  378121,
#  378130,
#  378142,
#  378175,
#  378179,
#  378185,
#  378197,
#  378218,
#  378225,
#  410846,
#  419436,
#  436223,
#  445830,
#  446592,
#  447804,
#  448011,
#  448043,
#  448306,
#  448662,
#  448754,
#  449068,
#  449233,
#  466098,
#  495816,
#  497906,
#  505724,
#  511510,
#  511749,
#  515845,
#  543421,
#  546306,
#  546690,
#  548204,
#  549638,
#  564852,
#  569369,
#  592569,
#  606334,
#  609619,
#  617429,
#  625536,
#  626019,
#  627775,
#  628030,
#  628032,
#  628033,
#  630304,
#  638141,
#  639819,
#  640898,
#  641161,
#  641163,
#  641822,
#  646016,
#  646381,
#  646643,
#  646757,
#  647308,
#  651518,
#  651624,
#  651857,
#  651859,
#  652264,
#  652480,
#  652699,
#  652800,
#  653045,
#  653156,
#  653270,
#  653863,
#  654077,
#  654226,
#  654256,
#  654363,
#  658373,
#  658466,
#  658467,
#  658607,
#  658656,
#  658833,
#  658900,
#  658986,
#  659172,
#  659371,
#  660195,
#  660201,
#  660635,
#  660712,
#  660762,
#  661042,
#  662182,
#  662407,
#  662413,
#  662524,
#  662568,
#  662704,
#  662912,
#  662984,
#  663520,
#  663635,
#  664048,
#  664342,
#  664568,
#  664570,
#  664571,
#  664572,
#  664573,
#  665991,
#  666098,
#  666925,
#  667108,
#  667156,
#  667728,
#  668565,
#  670859,
#  671043,
#  672273,
#  678892,
#  679470,
#  679473,
#  684097,
#  686753,
#  687589,
#  687925,
#  689588,
#  689895,
#  692917,
#  694474,
#  700411,
#  703115,
#  703658,
#  703803,
#  703911,
#  704075,
#  704560,
#  705165,
#  705168,
#  705845,
#  706380,
#  706764,
#  708961,
#  708994,
#  709126,
#  709578,
#  709706,
#  710987,
#  716302,
#  716509,
#  716965,
#  721282,
#  721918,
#  727266,
#  728722,
#  733746,
#  733748,
#  739639,
#  739951,
#  740329,
#  747268,
#  748002,
#  748224,
#  748227,
#  754906,
#  760763,
#  761353,
#  762204,
#  767563,
#  770174,
#  774716,
#  774807,
#  776098,
#  778513,
#  781663,
#  782022,
#  783409,
#  785880,
#  786011,
#  795710,
#  798466,
#  806793,
#  809189,
#  809799,
#  810159,
#  815635,
#  815913,
#  816466,
#  816577,
#  817639,
#  818574,
#  818918,
#  819011,
#  819013,
#  819111,
#  819348,
#  819568,
#  819902,
#  820761,
#  821235,
#  821325,
#  821503,
#  821879,
#  822442,
#  823170,
#  823898,
#  824090,
#  824527,
#  824887,
#  825012,
#  825240,
#  825306,
#  825562,
#  847001,
#  847094,
#  847387,
#  849042,
#  849329,
#  849434,
#  854994,
#  858017,
#  858235,
#  861498,
#  877522,
#  877745,
#  881925,
#  882847,
#  883031,
#  884107,
#  885383,
#  885908,
#  889944,
#  890067,
#  890308,
#  897411,
#  898008,
#  898542,
#  898544,
#  899359,
#  899361,
#  900135,
#  901127,
#  901702,
#  901866,
#  902180,
#  902720,
#  903401,
#  904225,
#  904847,
#  905198,
#  909105,
#  910562,
#  914943,
#  914944,
#  917697,
#  918211,
#  918412,
#  919132,
#  919501,
#  919864,
#  920930,
#  920932,
#  921205,
#  923419,
#  923420,
#  929180,
#  933165,
#  933166,
#  933793,
#  939173,
#  939318,
#  939324,
#  942590,
#  942591,
#  942592,
#  942593,
#  943379,
#  943380]

# %%
def sort_quarterly_reports(df, simfin_id):
    """
    Get the data for a given SIMFIN_ID and set the index to be
    the sorted Fiscal Year and Period so it is easier to see
    which ones are missing.
    """
    return df.set_index([SIMFIN_ID, FISCAL_YEAR, FISCAL_PERIOD]).sort_index().loc[simfin_id]

# %%
# Show all the reports for a given SIMFIN_ID sorted by
# Fiscal Year and Period so it is easier to see which are missing.
sort_quarterly_reports(df=df, simfin_id=139560)
# Out:
#                           Ticker Currency Report Date Publish Date  \
# Fiscal Year Fiscal Period
# 2012        Q1              REXR      USD  2012-03-31   2013-10-03
#             Q2              REXR      USD  2012-06-30   2013-10-03
# 2013        Q1              REXR      USD  2013-03-31   2013-10-03
#             Q2              REXR      USD  2013-06-30   2013-10-03
#             Q3              REXR      USD  2013-09-30   2013-11-13
# 2014        Q1              REXR      USD  2014-03-31   2014-05-14
#             Q2              REXR      USD  2014-06-30   2014-08-11
#             Q3              REXR      USD  2014-09-30   2014-11-06
#             Q4              REXR      USD  2014-12-31   2015-03-09
# 2015        Q1              REXR      USD  2015-03-31   2015-05-11
#             Q2              REXR      USD  2015-06-30   2015-08-10
#             Q3              REXR      USD  2015-09-30   2015-11-09
#             Q4              REXR      USD  2015-12-31   2016-02-25
# 2016        Q1              REXR      USD  2016-03-31   2016-05-10
#             Q2              REXR      USD  2016-06-30   2016-08-08
#             Q3              REXR      USD  2016-09-30   2016-11-07
#             Q4              REXR      USD  2016-12-31   2017-02-23
# 2017        Q1              REXR      USD  2017-03-31   2017-05-05
#             Q2              REXR      USD  2017-06-30   2017-08-04
#             Q3              REXR      USD  2017-09-30   2017-11-03
#             Q4              REXR      USD  2017-12-31   2018-02-21
# 2018        Q1              REXR      USD  2018-03-31   2018-05-07
#             Q2              REXR      USD  2018-06-30   2018-08-06
#             Q3              REXR      USD  2018-09-30   2018-11-01
#             Q4              REXR      USD  2018-12-31   2019-02-19
#
#                            Shares (Basic)  Shares (Diluted)     Revenue  \
# Fiscal Year Fiscal Period
# 2012        Q1                        NaN               NaN   7968000.0
#             Q2                        NaN               NaN   8234000.0
# 2013        Q1                        NaN               NaN   9317000.0
#             Q2                        NaN               NaN  10822000.0
#             Q3                 24574432.0        24574432.0   8980000.0
# 2014        Q1                 25419418.0        25419418.0  13691000.0
#             Q2                 25419757.0        25419757.0  14996000.0
#             Q3                 33527183.0        33527183.0  18036000.0
#             Q4                 43447666.0        43447666.0  19858000.0
# 2015        Q1                 50683528.0        50683528.0  21340000.0
#             Q2                 54963093.0        54963093.0  22722000.0
#             Q3                 55145963.0        55145963.0  23674000.0
#             Q4                 55307108.0        55307108.0  26164000.0
# 2016        Q1                 55269598.0        55416947.0  27504000.0
#             Q2                 64063337.0        64304713.0  30608000.0
#             Q3                 65707476.0        67985177.0  33303000.0
#             Q4                 65851673.0        64155379.0  34777000.0
# 2017        Q1                 66341138.0        66626239.0  35354000.0
#             Q2                 67920773.0        68331234.0  36782000.0
#             Q3                 72621219.0        73068081.0  43339000.0
#             Q4                 77912318.0        78369062.0  45880000.0
# 2018        Q1                 78694161.0        79196060.0  48536000.0
#             Q2                 82924208.0        83494825.0  51756000.0
#             Q3                 91463594.0        91945206.0  55194000.0
#             Q4                 94214977.0        94706905.0  57008000.0
#
#                            Cost of Revenue  Gross Profit  Operating Expenses  \
# Fiscal Year Fiscal Period
# 2012        Q1                  -1986000.0     5982000.0          -4607000.0
#             Q2                  -2184000.0     6050000.0          -4382000.0
# 2013        Q1                  -2120000.0     7197000.0          -4651000.0
#             Q2                  -2442000.0     8380000.0          -5404000.0
#             Q3                  -2527000.0     6453000.0          -5525000.0
# 2014        Q1                  -4134000.0     9557000.0          -8735000.0
#             Q2                  -3892000.0    11104000.0          -8783000.0
#             Q3                  -4879000.0    13157000.0         -11305000.0
#             Q4                  -5477000.0    14381000.0         -11929000.0
# 2015        Q1                  -5771000.0    15569000.0         -13430000.0
#             Q2                  -5874000.0    16848000.0         -14230000.0
#             Q3                  -6237000.0    17437000.0         -14420000.0
#             Q4                  -7118000.0    19046000.0         -14773000.0
# 2016        Q1                  -7543000.0    19961000.0         -14816000.0
#             Q2                  -7959000.0    22649000.0         -17131000.0
#             Q3                  -8978000.0    24325000.0         -18408000.0
#             Q4                  -9139000.0    25638000.0         -18467000.0
# 2017        Q1                  -9222000.0    26132000.0         -18685000.0
#             Q2                  -9536000.0    27246000.0         -19638000.0
#             Q3                 -11229000.0    32110000.0         -23814000.0
#             Q4                 -12152000.0    33728000.0         -24325000.0
# 2018        Q1                 -11960000.0    36576000.0         -25614000.0
#             Q2                 -12775000.0    38981000.0         -26281000.0
#             Q3                 -13294000.0    41900000.0         -26373000.0
#             Q4                 -13642000.0    43366000.0         -26968000.0
#
#                            ...  Non-Operating Income (Loss)  \
# Fiscal Year Fiscal Period  ...
# 2012        Q1             ...                   -4101000.0
#             Q2             ...                   -4436000.0
# 2013        Q1             ...                   -4070000.0
#             Q2             ...                   -5179000.0
#             Q3             ...                    -634000.0
# 2014        Q1             ...                   -1206000.0
#             Q2             ...                   -1588000.0
#             Q3             ...                   -1955000.0
#             Q4             ...                   -1680000.0
# 2015        Q1             ...                   -1825000.0
#             Q2             ...                   -1646000.0
#             Q3             ...                   -2200000.0
#             Q4             ...                   -2689000.0
# 2016        Q1             ...                   -3193000.0
#             Q2             ...                   -3654000.0
#             Q3             ...                   -2476000.0
#             Q4             ...                   -4074000.0
# 2017        Q1             ...                   -3987000.0
#             Q2             ...                   -4302000.0
#             Q3             ...                   -6271000.0
#             Q4             ...                   -5638000.0
# 2018        Q1             ...                   -5852000.0
#             Q2             ...                   -6452000.0
#             Q3             ...                   -6456000.0
#             Q4             ...                   -6656000.0
#
#                            Interest Expense, Net  \
# Fiscal Year Fiscal Period
# 2012        Q1                        -4158000.0
#             Q2                        -4346000.0
# 2013        Q1                        -3857000.0
#             Q2                        -4467000.0
#             Q3                         -717000.0
# 2014        Q1                        -1251000.0
#             Q2                        -1537000.0
#             Q3                        -1957000.0
#             Q4                        -1655000.0
# 2015        Q1                        -1826000.0
#             Q2                        -1658000.0
#             Q3                        -2245000.0
#             Q4                        -2724000.0
# 2016        Q1                        -3254000.0
#             Q2                        -3716000.0
#             Q3                        -3804000.0
#             Q4                        -4074000.0
# 2017        Q1                        -3998000.0
#             Q2                        -4302000.0
#             Q3                        -6271000.0
#             Q4                        -5638000.0
# 2018        Q1                        -5852000.0
#             Q2                        -6452000.0
#             Q3                        -6456000.0
#             Q4                        -6656000.0
#
#                            Pretax Income (Loss), Adjusted  \
# Fiscal Year Fiscal Period
# 2012        Q1                                   -2726000
#             Q2                                   -2768000
# 2013        Q1                                   -1524000
#             Q2                                   -2203000
#             Q3                                     294000
# 2014        Q1                                    -384000
#             Q2                                     733000
#             Q3                                    -103000
#             Q4                                     772000
# 2015        Q1                                     314000
#             Q2                                     972000
#             Q3                                     817000
#             Q4                                    1584000
# 2016        Q1                                    1952000
#             Q2                                    1864000
#             Q3                                    3441000
#             Q4                                    3097000
# 2017        Q1                                    3460000
#             Q2                                    3306000
#             Q3                                    2025000
#             Q4                                    3765000
# 2018        Q1                                    5110000
#             Q2                                    6248000
#             Q3                                    9071000
#             Q4                                    9742000
#
#                            Abnormal Gains (Losses)  Pretax Income (Loss)  \
# Fiscal Year Fiscal Period
# 2012        Q1                            544000.0              -2182000
#             Q2                            445000.0              -2323000
# 2013        Q1                           1284000.0               -240000
#             Q2                           -624000.0              -2827000
#             Q3                           -119000.0                175000
# 2014        Q1                           -333000.0               -717000
#             Q2                           -652000.0                 81000
#             Q3                           -576000.0               -679000
#             Q4                           -627000.0                145000
# 2015        Q1                           -233000.0                 81000
#             Q2                           -776000.0                196000
#             Q3                           -200000.0                617000
#             Q4                           -528000.0               1056000
# 2016        Q1                           -475000.0               1477000
#             Q2                          10928000.0              12792000
#             Q3                           -380000.0               3061000
#             Q4                           5449000.0               8546000
# 2017        Q1                           2261000.0               5721000
#             Q2                          16549000.0              19855000
#             Q3                            -16000.0               2009000
#             Q4                          10350000.0              14115000
# 2018        Q1                           9974000.0              15084000
#             Q2                           1571000.0               7819000
#             Q3                           -106000.0               8965000
#             Q4                           5465000.0              15207000
#
#                            Income Tax (Expense) Benefit, Net  \
# Fiscal Year Fiscal Period
# 2012        Q1                                           NaN
#             Q2                                           NaN
# 2013        Q1                                           NaN
#             Q2                                           NaN
#             Q3                                           NaN
# 2014        Q1                                           NaN
#             Q2                                           NaN
#             Q3                                           NaN
#             Q4                                           NaN
# 2015        Q1                                           NaN
#             Q2                                           NaN
#             Q3                                           NaN
#             Q4                                           NaN
# 2016        Q1                                           NaN
#             Q2                                           NaN
#             Q3                                           NaN
#             Q4                                           NaN
# 2017        Q1                                           NaN
#             Q2                                           NaN
#             Q3                                           NaN
#             Q4                                           NaN
# 2018        Q1                                           NaN
#             Q2                                           NaN
#             Q3                                           NaN
#             Q4                                           NaN
#
#                            Income (Loss) From Continuing Operations  \
# Fiscal Year Fiscal Period
# 2012        Q1                                             -2182000
#             Q2                                             -2323000
# 2013        Q1                                              -240000
#             Q2                                             -2827000
#             Q3                                               175000
# 2014        Q1                                              -717000
#             Q2                                                81000
#             Q3                                              -679000
#             Q4                                               145000
# 2015        Q1                                                81000
#             Q2                                               196000
#             Q3                                               617000
#             Q4                                              1056000
# 2016        Q1                                              1477000
#             Q2                                             12792000
#             Q3                                              3061000
#             Q4                                              8546000
# 2017        Q1                                              5721000
#             Q2                                             19855000
#             Q3                                              2009000
#             Q4                                             14115000
# 2018        Q1                                             15084000
#             Q2                                              7819000
#             Q3                                              8965000
#             Q4                                             15207000
#
#                            Net Extraordinary Gains (Losses)  Net Income  \
# Fiscal Year Fiscal Period
# 2012        Q1                                      77000.0     -172000
#             Q2                                    -145000.0    -1459000
# 2013        Q1                                    2294000.0      328000
#             Q2                                    2359000.0    -2286000
#             Q3                                     120000.0      256000
# 2014        Q1                                    2146000.0     1277000
#             Q2                                          NaN       73000
#             Q3                                          NaN     -599000
#             Q4                                          NaN      145000
# 2015        Q1                                          NaN       77000
#             Q2                                          NaN      188000
#             Q3                                          NaN      593000
#             Q4                                          NaN     1016000
# 2016        Q1                                          NaN     1425000
#             Q2                                          NaN    12374000
#             Q3                                          NaN     2998000
#             Q4                                          NaN     8329000
# 2017        Q1                                          NaN     5589000
#             Q2                                          NaN    19324000
#             Q3                                          NaN     1988000
#             Q4                                          NaN    13811000
# 2018        Q1                                          NaN    14766000
#             Q2                                          NaN     7690000
#             Q3                                          NaN     8824000
#             Q4                                          NaN    14930000
#
#                            Net Income Available to Common Shareholders
# Fiscal Year Fiscal Period
# 2012        Q1                                                 -172000
#             Q2                                                -1459000
# 2013        Q1                                                  328000
#             Q2                                                -2286000
#             Q3                                                  256000
# 2014        Q1                                                 1261000
#             Q2                                                   49000
#             Q3                                                 -623000
#             Q4                                                  107000
# 2015        Q1                                                   27000
#             Q2                                                  139000
#             Q3                                                  540000
#             Q4                                                  945000
# 2016        Q1                                                 1347000
#             Q2                                                12299000
#             Q3                                                 2267000
#             Q4                                                 6928000
# 2017        Q1                                                 4176000
#             Q2                                                17846000
#             Q3                                                  586000
#             Q4                                                11819000
# 2018        Q1                                                12246000
#             Q2                                                 5172000
#             Q3                                                 6307000
#             Q4                                                12413000
#
# [25 rows x 24 columns]

# %% [markdown]
# ## Missing TTM Reports
#
# Trailing-Twelve-Months (TTM) data is also quarterly so we can use the same helper-functions from above.

# %%
test_name = "Missing ttm reports"
test_func = lambda df: len(missing_quarterly_reports(df=df)) > 0
test_datasets(datasets=datasets_fundamental,
              variants=['ttm'],
              test_name=test_name, test_func=test_func)
# Out:
# Missing ttm reports
# dataset='income', variant='ttm', market='de'
# dataset='income', variant='ttm', market='sg'
# dataset='income', variant='ttm', market='us'
# dataset='income-insurance', variant='ttm', market='us'
# dataset='balance', variant='ttm', market='de'
# dataset='balance', variant='ttm', market='us'
# dataset='balance-banks', variant='ttm', market='de'
# dataset='balance-banks', variant='ttm', market='us'
# dataset='balance-insurance', variant='ttm', market='us'
# dataset='cashflow', variant='ttm', market='de'
# dataset='cashflow', variant='ttm', market='us'
# dataset='cashflow-banks', variant='ttm', market='de'
# dataset='cashflow-banks', variant='ttm', market='us'
# dataset='cashflow-insurance', variant='ttm', market='us'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-48-5574c31fa9ec> in <module>
#       3 test_datasets(datasets=datasets_fundamental,
#       4               variants=['ttm'],
# ----> 5               test_name=test_name, test_func=test_func)
#
# <ipython-input-7-b3d44117203b> in test_datasets(test_name, datasets, variants, markets, test_func, test_func_rows, process_df_none, raise_exception)
#      98     # Raise exception?
#      99     if num_problems>0 and raise_exception:
# --> 100         raise Exception(test_name)
#
# Exception: Missing ttm reports

# %%
# Get list of SIMFIN_ID's that have missing reports for a dataset.
df = data.get(dataset='income', variant='ttm', market='us')
missing_quarterly_reports(df=df)
# Out:
# [67201,
#  89750,
#  117690,
#  133865,
#  181659,
#  188922,
#  233893,
#  257294,
#  258154,
#  337852,
#  340222,
#  353395,
#  370817,
#  378142,
#  410846,
#  419436,
#  436223,
#  446592,
#  515845,
#  592569,
#  609619,
#  625536,
#  626019,
#  628033,
#  630304,
#  646016,
#  651624,
#  652699,
#  653156,
#  653270,
#  654363,
#  658373,
#  658466,
#  659172,
#  660762,
#  662524,
#  662568,
#  662704,
#  679470,
#  689588,
#  703911,
#  705165,
#  705845,
#  708961,
#  708994,
#  727266,
#  728722,
#  733746,
#  767563,
#  776098,
#  778513,
#  786011,
#  798466,
#  815635,
#  819348,
#  819902,
#  823898,
#  824090,
#  824527,
#  824887,
#  825012,
#  849042,
#  877522,
#  889944,
#  890308,
#  899359,
#  901127,
#  901866,
#  905198,
#  910562,
#  919132,
#  919501,
#  923419,
#  933165,
#  942591,
#  942592]

# %%
# Show all the reports for a given SIMFIN_ID sorted by
# Fiscal Year and Period so it is easier to see which are missing.
sort_quarterly_reports(df=df, simfin_id=89750)
# Out:
#                           Ticker Currency Report Date Publish Date  \
# Fiscal Year Fiscal Period
# 2008        Q4               DHR      USD  2008-12-31   2009-10-22
# 2009        Q1               DHR      USD  2009-03-31   2010-04-22
#             Q2               DHR      USD  2009-06-30   2009-07-23
#             Q3               DHR      USD  2009-09-30   2009-10-22
# 2010        Q4               DHR      USD  2010-12-31   2011-02-24
# 2011        Q1               DHR      USD  2011-03-31   2011-04-21
#             Q2               DHR      USD  2011-06-30   2011-07-27
#             Q3               DHR      USD  2011-09-30   2011-10-20
#             Q4               DHR      USD  2011-12-31   2012-02-24
# 2012        Q1               DHR      USD  2012-03-31   2012-04-19
#             Q2               DHR      USD  2012-06-30   2012-07-19
#             Q3               DHR      USD  2012-09-30   2012-10-18
#             Q4               DHR      USD  2012-12-31   2013-02-22
# 2013        Q1               DHR      USD  2013-03-31   2013-04-18
#             Q2               DHR      USD  2013-06-30   2013-07-18
#             Q3               DHR      USD  2013-09-30   2013-10-17
#             Q4               DHR      USD  2013-12-31   2014-02-21
# 2014        Q1               DHR      USD  2014-03-31   2014-04-16
#             Q2               DHR      USD  2014-06-30   2014-07-17
#             Q3               DHR      USD  2014-09-30   2014-10-16
#             Q4               DHR      USD  2014-12-31   2015-02-25
# 2015        Q1               DHR      USD  2015-03-31   2015-04-23
#             Q2               DHR      USD  2015-06-30   2015-07-23
#             Q3               DHR      USD  2015-09-30   2015-10-22
#             Q4               DHR      USD  2015-12-31   2016-02-24
# 2016        Q1               DHR      USD  2016-03-31   2016-04-21
#             Q2               DHR      USD  2016-06-30   2016-07-25
#             Q3               DHR      USD  2016-09-30   2016-10-20
#             Q4               DHR      USD  2016-12-31   2017-02-22
# 2017        Q1               DHR      USD  2017-03-31   2017-04-20
#             Q2               DHR      USD  2017-06-30   2017-07-20
#             Q3               DHR      USD  2017-09-30   2017-10-19
#             Q4               DHR      USD  2017-12-31   2018-02-21
# 2018        Q1               DHR      USD  2018-03-31   2018-04-19
#             Q2               DHR      USD  2018-06-30   2018-07-19
#             Q3               DHR      USD  2018-09-30   2018-10-18
#             Q4               DHR      USD  2018-12-31   2019-02-21
# 2019        Q1               DHR      USD  2019-03-31   2019-04-18
#
#                            Shares (Basic)  Shares (Diluted)       Revenue  \
# Fiscal Year Fiscal Period
# 2008        Q4                843114360.0       886680300.0  1.269746e+10
# 2009        Q1                843466140.0       885034260.0  1.229633e+10
#             Q2                843916920.0       883707000.0  1.168604e+10
#             Q3                844712880.0       883003440.0  1.122855e+10
# 2010        Q4                862224000.0       901956000.0  1.255000e+10
# 2011        Q1                866392230.0       904663980.0  1.283437e+10
#             Q2                871252800.0       908710110.0  1.325281e+10
#             Q3                882030600.0       917610870.0  1.460576e+10
#             Q4                892584000.0       925584000.0  1.609050e+10
# 2012        Q1                902451330.0       934055760.0  1.711450e+10
#             Q2                911821020.0       940755090.0  1.803213e+10
#             Q3                914441550.0       941909100.0  1.800184e+10
#             Q4                915288000.0       941292000.0  1.826040e+10
# 2013        Q1                915453000.0       939444000.0  1.838890e+10
#             Q2                915321000.0       937761000.0  1.857290e+10
#             Q3                916146000.0       937101000.0  1.882650e+10
#             Q4                918720000.0       938520000.0  1.828310e+10
# 2014        Q1                921393000.0       940632000.0  1.850110e+10
#             Q2                923373000.0       942546000.0  1.872720e+10
#             Q3                924990000.0       943965000.0  1.876520e+10
#             Q4                702200000.0       716100000.0  1.286690e+10
# 2015        Q1                704543000.0       717387000.0  1.289890e+10
#             Q2                650522000.0       661139000.0  1.289550e+10
#             Q3                590789000.0       599468000.0  1.170060e+10
#             Q4                698100000.0       708500000.0  1.443370e+10
# 2016        Q1                636874000.0       645604000.0  1.366310e+10
#             Q2                632224000.0       640429000.0  1.294480e+10
#             Q3                633149000.0       641079000.0  1.356470e+10
#             Q4                691200000.0       699800000.0  1.688240e+10
# 2017        Q1                692625000.0       701950000.0  1.716400e+10
#             Q2                693750000.0       703575000.0  1.743220e+10
#             Q3                694750000.0       704650000.0  1.782830e+10
#             Q4                695800000.0       706100000.0  1.832970e+10
# 2018        Q1                696875000.0       707050000.0  1.881940e+10
#             Q2                698075000.0       708075000.0  1.929030e+10
#             Q3                699375000.0       709325000.0  1.961520e+10
#             Q4                700600000.0       710200000.0  1.989300e+10
# 2019        Q1                702850000.0       712450000.0  2.007750e+10
#
#                            Cost of Revenue  Gross Profit  Operating Expenses  \
# Fiscal Year Fiscal Period
# 2008        Q4               -6.757262e+09  5.940194e+09       -4.070717e+09
# 2009        Q1               -6.515239e+09  5.781087e+09       -3.984613e+09
#             Q2               -6.202983e+09  5.483057e+09       -3.853101e+09
#             Q3               -5.935108e+09  5.293444e+09       -3.806149e+09
# 2010        Q4               -6.145500e+09  6.404500e+09       -4.377700e+09
# 2011        Q1               -6.149731e+09  6.684638e+09       -4.509005e+09
#             Q2               -6.256175e+09  6.996637e+09       -4.743273e+09
#             Q3               -7.037980e+09  7.567783e+09       -5.229818e+09
#             Q4               -7.913900e+09  8.176600e+09       -5.626200e+09
# 2012        Q1               -8.451252e+09  8.663250e+09       -5.962728e+09
#             Q2               -8.930933e+09  9.101198e+09       -6.202873e+09
#             Q3               -8.805727e+09  9.196117e+09       -6.187656e+09
#             Q4               -8.846100e+09  9.414300e+09       -6.319100e+09
# 2013        Q1               -8.884400e+09  9.504500e+09       -6.398900e+09
#             Q2               -8.928400e+09  9.644500e+09       -6.488600e+09
#             Q3               -9.035300e+09  9.791200e+09       -6.560200e+09
#             Q4               -8.941100e+09  9.342000e+09       -6.221500e+09
# 2014        Q1               -9.031900e+09  9.469200e+09       -6.290700e+09
#             Q2               -9.133300e+09  9.593900e+09       -6.369700e+09
#             Q3               -9.143700e+09  9.621500e+09       -6.343500e+09
#             Q4               -6.017400e+09  6.849500e+09       -4.804500e+09
# 2015        Q1               -6.034100e+09  6.864800e+09       -4.853600e+09
#             Q2               -6.006900e+09  6.888600e+09       -4.832300e+09
#             Q3               -5.370900e+09  6.329700e+09       -4.659600e+09
#             Q4               -6.662600e+09  7.771100e+09       -5.608900e+09
# 2016        Q1               -6.192900e+09  7.470200e+09       -5.450000e+09
#             Q2               -5.737300e+09  7.207500e+09       -5.411600e+09
#             Q3               -5.964600e+09  7.600100e+09       -5.585100e+09
#             Q4               -7.547800e+09  9.334600e+09       -6.583700e+09
# 2017        Q1               -7.662400e+09  9.501600e+09       -6.739900e+09
#             Q2               -7.829600e+09  9.602600e+09       -6.867300e+09
#             Q3               -7.974900e+09  9.853400e+09       -7.049700e+09
#             Q4               -8.137200e+09  1.019250e+10       -7.171300e+09
# 2018        Q1               -8.317600e+09  1.050180e+10       -7.361500e+09
#             Q2               -8.453700e+09  1.083660e+10       -7.512500e+09
#             Q3               -8.624900e+09  1.099030e+10       -7.603000e+09
#             Q4               -8.785900e+09  1.110710e+10       -7.703300e+09
# 2019        Q1               -8.896000e+09  1.118150e+10       -7.796900e+09
#
#                            ...  Non-Operating Income (Loss)  \
# Fiscal Year Fiscal Period  ...
# 2008        Q4             ...                 -120170000.0
# 2009        Q1             ...                 -106415000.0
#             Q2             ...                 -104176000.0
#             Q3             ...                  -20158000.0
# 2010        Q4             ...                  -88200000.0
# 2011        Q1             ...                  -73558000.0
#             Q2             ...                  -60325000.0
#             Q3             ...                  -67383000.0
#             Q4             ...                  -69700000.0
# 2012        Q1             ...                  -80151000.0
#             Q2             ...                  -84679000.0
#             Q3             ...                  -78900000.0
#             Q4             ...                  -84400000.0
# 2013        Q1             ...                  -98400000.0
#             Q2             ...                 -117000000.0
#             Q3             ...                 -130400000.0
#             Q4             ...                  295800000.0
# 2014        Q1             ...                  306500000.0
#             Q2             ...                  334000000.0
#             Q3             ...                  379800000.0
#             Q4             ...                   41200000.0
# 2015        Q1             ...                   41800000.0
#             Q2             ...                   25400000.0
#             Q3             ...                  -12900000.0
#             Q4             ...                 -122800000.0
# 2016        Q1             ...                   74700000.0
#             Q2             ...                   45900000.0
#             Q3             ...                   28400000.0
#             Q4             ...                   39200000.0
# 2017        Q1             ...                 -170000000.0
#             Q2             ...                 -153400000.0
#             Q3             ...                 -147500000.0
#             Q4             ...                  -82400000.0
# 2018        Q1             ...                  -73600000.0
#             Q2             ...                  -67100000.0
#             Q3             ...                  -58800000.0
#             Q4             ...                 -111000000.0
# 2019        Q1             ...                  -83500000.0
#
#                            Interest Expense, Net  \
# Fiscal Year Fiscal Period
# 2008        Q4                      -120170000.0
# 2009        Q1                      -106415000.0
#             Q2                      -104176000.0
#             Q3                      -105276000.0
# 2010        Q4                      -111000000.0
# 2011        Q1                      -110833000.0
#             Q2                      -112060000.0
#             Q3                      -124559000.0
#             Q4                      -136500000.0
# 2012        Q1                      -146876000.0
#             Q2                      -154944000.0
#             Q3                      -151674000.0
#             Q4                      -154300000.0
# 2013        Q1                      -153900000.0
#             Q2                      -154500000.0
#             Q3                      -149400000.0
#             Q4                      -135500000.0
# 2014        Q1                      -124800000.0
#             Q2                      -116500000.0
#             Q3                      -108900000.0
#             Q4                       -81400000.0
# 2015        Q1                       -80800000.0
#             Q2                       -78000000.0
#             Q3                       -90500000.0
#             Q4                      -135200000.0
# 2016        Q1                      -161100000.0
#             Q2                      -189900000.0
#             Q3                      -195000000.0
#             Q4                      -184200000.0
# 2017        Q1                      -170000000.0
#             Q2                      -153400000.0
#             Q3                      -147500000.0
#             Q4                      -155200000.0
# 2018        Q1                      -154200000.0
#             Q2                      -156000000.0
#             Q3                      -156800000.0
#             Q4                      -148200000.0
# 2019        Q1                      -118100000.0
#
#                            Pretax Income (Loss), Adjusted  \
# Fiscal Year Fiscal Period
# 2008        Q4                                 1749307000
# 2009        Q1                                 1690059000
#             Q2                                 1525780000
#             Q3                                 1467137000
# 2010        Q4                                 1938600000
# 2011        Q1                                 2102075000
#             Q2                                 2193039000
#             Q3                                 2270582000
#             Q4                                 2480700000
# 2012        Q1                                 2620371000
#             Q2                                 2813646000
#             Q3                                 2929561000
#             Q4                                 3010800000
# 2013        Q1                                 3007200000
#             Q2                                 3038900000
#             Q3                                 3100600000
#             Q4                                 3416300000
# 2014        Q1                                 3485000000
#             Q2                                 3558200000
#             Q3                                 3657800000
#             Q4                                 2086200000
# 2015        Q1                                 2053000000
#             Q2                                 2081700000
#             Q3                                 1657200000
#             Q4                                 2039400000
# 2016        Q1                                 2094900000
#             Q2                                 1841800000
#             Q3                                 2043400000
#             Q4                                 2790100000
# 2017        Q1                                 2591700000
#             Q2                                 2581900000
#             Q3                                 2656200000
#             Q4                                 2938800000
# 2018        Q1                                 3066700000
#             Q2                                 3257000000
#             Q3                                 3328500000
#             Q4                                 3292800000
# 2019        Q1                                 3301100000
#
#                            Abnormal Gains (Losses)  Pretax Income (Loss)  \
# Fiscal Year Fiscal Period
# 2008        Q4                                 NaN            1749307000
# 2009        Q1                                 NaN            1690059000
#             Q2                                 NaN            1525780000
#             Q3                                 NaN            1467137000
# 2010        Q4                                 NaN            2229600000
# 2011        Q1                                 NaN            2393075000
#             Q2                                 NaN            2484039000
#             Q3                                 NaN            2237658000
#             Q4                                 NaN            2447800000
# 2012        Q1                                 NaN            2587471000
#             Q2                                 NaN            2780746000
#             Q3                                 NaN            2929548000
#             Q4                                 NaN            3010800000
# 2013        Q1                                 NaN            3237000000
#             Q2                                 NaN            3268700000
#             Q3                                 NaN            3330400000
#             Q4                                 NaN            3416300000
# 2014        Q1                                 NaN            3255200000
#             Q2                                 NaN            3328400000
#             Q3                                 NaN            3428000000
#             Q4                                 NaN            2086200000
# 2015        Q1                                 NaN            2053000000
#             Q2                                 NaN            2081700000
#             Q3                                 NaN            1657200000
#             Q4                                 NaN            2039400000
# 2016        Q1                                 NaN            2094900000
#             Q2                                 NaN            1841800000
#             Q3                                 NaN            1864600000
#             Q4                                 NaN            2611300000
# 2017        Q1                                 NaN            2412900000
#             Q2                                 NaN            2403100000
#             Q3                                 NaN            2656200000
#             Q4                                 NaN            2938800000
# 2018        Q1                                 NaN            3066700000
#             Q2                                 NaN            3257000000
#             Q3                                 NaN            3328500000
#             Q4                                 NaN            3292800000
# 2019        Q1                                 NaN            3301100000
#
#                            Income Tax (Expense) Benefit, Net  \
# Fiscal Year Fiscal Period
# 2008        Q4                                  -431676000.0
# 2009        Q1                                  -411221000.0
#             Q2                                  -314696000.0
#             Q3                                  -276682000.0
# 2010        Q4                                  -511400000.0
# 2011        Q1                                  -550847000.0
#             Q2                                  -564384000.0
#             Q3                                  -436399000.0
#             Q4                                  -512500000.0
# 2012        Q1                                  -548946000.0
#             Q2                                  -581571000.0
#             Q3                                  -697081000.0
#             Q4                                  -711500000.0
# 2013        Q1                                  -765800000.0
#             Q2                                  -780900000.0
#             Q3                                  -794300000.0
#             Q4                                  -825700000.0
# 2014        Q1                                  -776800000.0
#             Q2                                  -790400000.0
#             Q3                                  -805700000.0
#             Q4                                  -447500000.0
# 2015        Q1                                  -436000000.0
#             Q2                                  -425600000.0
#             Q3                                  -302500000.0
#             Q4                                  -292700000.0
# 2016        Q1                                  -320400000.0
#             Q2                                  -364800000.0
#             Q3                                  -364900000.0
#             Q4                                  -457900000.0
# 2017        Q1                                  -361500000.0
#             Q2                                  -212400000.0
#             Q3                                  -296000000.0
#             Q4                                  -469000000.0
# 2018        Q1                                  -514100000.0
#             Q2                                  -587900000.0
#             Q3                                  -567800000.0
#             Q4                                  -641900000.0
# 2019        Q1                                  -883000000.0
#
#                            Income (Loss) From Continuing Operations  \
# Fiscal Year Fiscal Period
# 2008        Q4                                           1317631000
# 2009        Q1                                           1278838000
#             Q2                                           1211084000
#             Q3                                           1190455000
# 2010        Q4                                           1718200000
# 2011        Q1                                           1842228000
#             Q2                                           1919655000
#             Q3                                           1801259000
#             Q4                                           1935300000
# 2012        Q1                                           2038525000
#             Q2                                           2199175000
#             Q3                                           2232467000
#             Q4                                           2299300000
# 2013        Q1                                           2471200000
#             Q2                                           2487800000
#             Q3                                           2536100000
#             Q4                                           2590600000
# 2014        Q1                                           2478400000
#             Q2                                           2538000000
#             Q3                                           2622300000
#             Q4                                           1638700000
# 2015        Q1                                           1617000000
#             Q2                                           1656100000
#             Q3                                           1354700000
#             Q4                                           1746700000
# 2016        Q1                                           1774500000
#             Q2                                           1477000000
#             Q3                                           1499700000
#             Q4                                           2153400000
# 2017        Q1                                           2051400000
#             Q2                                           2190700000
#             Q3                                           2360200000
#             Q4                                           2469800000
# 2018        Q1                                           2552600000
#             Q2                                           2669100000
#             Q3                                           2760700000
#             Q4                                           2650900000
# 2019        Q1                                           2418100000
#
#                            Net Extraordinary Gains (Losses)  Net Income  \
# Fiscal Year Fiscal Period
# 2008        Q4                                          NaN  1317631000
# 2009        Q1                                          NaN  1278838000
#             Q2                                          NaN  1211084000
#             Q3                                          NaN  1190455000
# 2010        Q4                                 7.480000e+07  1793000000
# 2011        Q1                                 7.989700e+07  1922125000
#             Q2                                 2.787580e+08  2198413000
#             Q3                                 2.741470e+08  2075406000
#             Q4                                 2.370000e+08  2172300000
# 2012        Q1                                 3.173170e+08  2355842000
#             Q2                                 1.081030e+08  2307278000
#             Q3                                 1.000830e+08  2332550000
#             Q4                                 9.290000e+07  2392200000
# 2013        Q1                                          NaN  2471200000
#             Q2                                          NaN  2487800000
#             Q3                                          NaN  2536100000
#             Q4                                          NaN  2695000000
# 2014        Q1                                          NaN  2582800000
#             Q2                                          NaN  2642400000
#             Q3                                          NaN  2726000000
#             Q4                                          NaN  2598400000
# 2015        Q1                                          NaN  2588500000
#             Q2                                          NaN  2607800000
#             Q3                                          NaN  3330500000
#             Q4                                 1.610700e+09  3357400000
# 2016        Q1                                 1.771500e+09  3546000000
#             Q2                                 2.030000e+09  3507000000
#             Q3                                 9.956000e+08  2495300000
#             Q4                                 4.003000e+08  2553700000
# 2017        Q1                                 2.500000e+08  2301400000
#             Q2                                 1.130000e+07  2202000000
#             Q3                                 2.230000e+07  2382500000
#             Q4                                 2.230000e+07  2492100000
# 2018        Q1                                 0.000000e+00  2552600000
#             Q2                                 0.000000e+00  2669100000
#             Q3                                 0.000000e+00  2760700000
#             Q4                                 0.000000e+00  2650900000
# 2019        Q1                                          NaN  2418100000
#
#                            Net Income Available to Common Shareholders
# Fiscal Year Fiscal Period
# 2008        Q4                                              1317631000
# 2009        Q1                                              1278838000
#             Q2                                              1211084000
#             Q3                                              1190455000
# 2010        Q4                                              1793000000
# 2011        Q1                                              1922125000
#             Q2                                              2198413000
#             Q3                                              2075406000
#             Q4                                              2172300000
# 2012        Q1                                              2355842000
#             Q2                                              2307278000
#             Q3                                              2332550000
#             Q4                                              2392200000
# 2013        Q1                                              2471200000
#             Q2                                              2487800000
#             Q3                                              2536100000
#             Q4                                              2695000000
# 2014        Q1                                              2582800000
#             Q2                                              2642400000
#             Q3                                              2726000000
#             Q4                                              2598400000
# 2015        Q1                                              2588500000
#             Q2                                              2607800000
#             Q3                                              3330500000
#             Q4                                              3357400000
# 2016        Q1                                              3546000000
#             Q2                                              3507000000
#             Q3                                              2495300000
#             Q4                                              2553700000
# 2017        Q1                                              2301400000
#             Q2                                              2202000000
#             Q3                                              2382500000
#             Q4                                              2492100000
# 2018        Q1                                              2552600000
#             Q2                                              2669100000
#             Q3                                              2760700000
#             Q4                                              2650900000
# 2019        Q1                                              2418100000
#
# [38 rows x 24 columns]
